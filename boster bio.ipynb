# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
s="https://www.bosterbio.com/unconjugated-goat-anti-rabbit-igg-secondary-antibody-ba1039-boster.html"
 #s="https://www.bosterbio.com/products/primary-antibodies.html?p="+str(i+1)
source=requests.get(s).text
soup=BeautifulSoup(source,'lxml')

# %%
def introduction(soup):
    try:
        
        b=[]
        background=soup.find('h2',text='Introduction').findNext('p').text
        background_next=str(soup.find('h2',text='Introduction').findNext('p').next_sibling.next_sibling)
        b.append(background)
        if "<p>" in background_next:
            b.append(background_next)
        b=' | '.join(b)    
        intro={}
        intro.update({"Introduction":b})
    except:
        pass
    return intro

# %%
urls=[]
secondar_antibodies=pd.read_excel("C:/Users/omama/Downloads/Data files/boster_bio_secondary_antobodies_clean_data.xlsx")
sec_urls=list(secondar_antibodies["Column96"][1:])
sec_urls
for su in sec_urls:
    su=su.split()
    urls.append(su[-1])
urls
# Out:
# ['BA1001;',
#  'BA1003;',
#  'BA1004;',
#  'BA1005;',
#  'BA1006;',
#  'BA1020;',
#  'BA1022;',
#  'BA1025;',
#  'BA1026;',
#  'BM2001;',
#  'BM2004;',
#  'GA1003;',
#  'GA1004;',
#  'GA1013;',
#  'GA1014;',
#  'GA1053;',
#  'GA1054;',
#  'BA1031;',
#  'BA1032;',
#  'BA1034;',
#  'BA1035;',
#  'BA1037;',
#  'BA1126;',
#  'BA1127;',
#  'BA1128;',
#  'BA1101;',
#  'BA1105;',
#  'BA1108;',
#  'BA1110;',
#  'BA1112;',
#  'BA1114;',
#  'BA1116;',
#  'BA1120;',
#  'BA1125;',
#  'BM2003;',
#  'BA1050;',
#  'BA1054;',
#  'BA1058;',
#  'BA1060;',
#  'BA1066;',
#  'BA1070;',
#  'BA1075;',
#  'BA1077;',
#  'BA1080;',
#  'BA1081;',
#  'BA1082;',
#  'BA1088;',
#  'BA1089;',
#  'BA1090;',
#  'BA1091;',
#  'BA1092;',
#  'BA1093;',
#  'BA1038;',
#  'BA1039;',
#  'BA1040;',
#  'BA1041;',
#  'BA1042;',
#  'BA1043;',
#  'BA1044;',
#  'BA1045;',
#  'BA1048;',
#  'SA2010;',
#  'SA2001;',
#  'SA2002;',
#  'SA2003;',
#  'SA2004;',
#  'SA2005;',
#  'SA1020;',
#  'SA1021;',
#  'SA1022;',
#  'SA1023;',
#  'SA1024;',
#  'SA1025;',
#  'SA1026;',
#  'SA1027;',
#  'SA1028;',
#  'SA1050;',
#  'SA1051;',
#  'SA1052;',
#  'SA1053;',
#  'SA1054;',
#  'SA1055;',
#  'SA1056;',
#  'SA1062;',
#  'SA1063;',
#  'SA1064;',
#  'SA1066;',
#  'SA1068;',
#  'SA1069;',
#  'SA1072;',
#  'SA1073;',
#  'SA1074;',
#  'SA1076;',
#  'SA1078;',
#  'SA1079;',
#  'SA1092;',
#  'SA1093;',
#  'SA1094;',
#  'SA1096;',
#  'SA1098;',
#  'SA1099;',
#  'SA1080;',
#  'SA1081;',
#  'SA1082;',
#  'SA1083;',
#  'SA1084;',
#  'SA1085;',
#  'SV0001-1;',
#  'SV0001-2;',
#  'SV0002-1;',
#  'SV0002-2;',
#  'SV0003-1;',
#  'SV0003-2;',
#  'EK1001;',
#  'EK1002;',
#  'EK1003;',
#  'EK1004;',
#  'EK1005;',
#  'SA2020;',
#  'SA2021;',
#  'SA2022;',
#  'SA2023;',
#  'SA2024;',
#  'SA2025;',
#  'BA1141;',
#  'BA1142;',
#  'BA1083;',
#  'BA1121;',
#  'GA1056;',
#  'GA1055;']

# %%
# Out:
# 9090

# %%
all_urls_primary_antibody=[]
for i in range(50):
    s="https://www.bosterbio.com/products/primary-antibodies.html?p="+str(i+1)
    source=requests.get(s).text
    soup=BeautifulSoup(source,'lxml')
    links_check=soup.findAll('a',{"class":"product-item-link"})
    for lnk in links_check:
        all_urls_primary_antibody.append(lnk)

# %%
d_links=[]
for i in range(len(all_urls_primary_antibody)):
    if all_urls_primary_antibody[i] in urls:
        pass
    elif all_urls_primary_antibody[i] not in urls:
        d_links.append(all_urls_primary_antibody[i])
len(d_links)
# Out:
# 500

# %%
source=requests.get(s).text
soup=BeautifulSoup(source,'lxml')

# %%
# Out:
# 500

# %%
def para_data(soup):
    dictt={}
    try:
        deal=[]
        details=soup.find('div',{"class":"product_main_column"})
        details=details.findAll(['h2','p'])
        details
        for n,det in enumerate(details):
            deal.append(str(det))


        deal=' '.join(deal) 
        deal=deal.split("<h2>")
        for d in deal:
            d=d.split("</h2>")
            if len(d)>1:
                dictt.update({d[0].lower():d[1]})
    except:
        pass

    return dictt
def introduction(soup):
    intro={}
    try:
        
        b=[]
        background=soup.find('h2',text='Introduction').findNext('p').text
        background_next=str(soup.find('h2',text='Introduction').findNext('p').next_sibling.next_sibling)
        b.append(background)
        if "<p>" in background_next:
            b.append(background_next)
        b=' | '.join(b)    
        
        intro.update({"Introduction":b})
    except:
        pass
    return intro
def publications(soup):
    publicat={}
    try:
        
        pubtext_list=[]
        pubalpha_list=[]
        pub=soup.find('div',{"class":"publications product_publications"})
        pub_text=pub.findAll("div",{"class":"col-md-9"})
        pub_alpha=pub.findAll("div",{"class":"col-md-3"})
        for pt in pub_text:
            pubtext_list.append(pt.text)
        pub_alpha    
        for pa in pub_alpha:
            pubalpha_list.append(pa.a["href"])    
        for i in range(len(pub_alpha)):
            if i==10:
                break
            publicat.update({"Publication_"+str(i+1):pubtext_list[i],"Publication_link_"+str(i+1):pubalpha_list[i]})
    except:
        pass
    return publicat    
   
def target_info(soup):
    try:
        target={}
        ti=soup.find('div',{"id":"target-info"})
        target.update({"Target Info":ti.find('p').text})
    except:
        pass
    return target

def assay_details(soup):
    assay_tab={}
    try:
        assay=soup.find('div',{"id":"assay-details"})
        assay=assay.findAll('p')
        a_table=[]
        for at in assay:
            a_table.append(at.text)
        a_table=' | '.join(a_table)
        assay_tab.update({"Assay Details":a_table})
    except:
        pass
    return assay_tab

def image_details(soup):
    images_det={}
    image_details=soup.findAll('div',{"class":"assay-details p-2"})
    for n,i_d in enumerate(image_details):
        try:
            img=i_d.find('img')
        except:
            pass
        #print(img['src'])
        para_d=[]
        try:
            para=i_d.findAll('p')
            for p in para:
                para_d.append(p.text)
            para_d=' | '.join(para_d)
        except:
            pass
        try:
            images_det.update({"Image_"+str(n+1):img['src']})
        except:
            pass
        try:
            images_det.update({"Image_"+str(n+1)+"_description":para_d})
        except:
            imshow=soup.findAll('div',{"class":"active carousel-item"})
            for im in imshow:
                im=im.findAll('img')
                for b in im:
                    images_det.update({b['src']})
                    
    return images_det    
def pro_title(soup):
    title_d={}
    tit=soup.find('h1',{"class":"page-title"}).text
    title_d.update({"Product Title":tit})
    return title_d
    
def pdf_sheet(soup):
    pdf={}
    datasheets=soup.findAll('div',{"class":"float-left file-icon"})
    try:
        for ds in datasheets:
            alpha=ds.find('a')
            alpha=alpha['href']
            para=ds.find('p').text
            pdf.update({para:alpha})
    except:
        pass
    return pdf

def tables(soup):
    tab_inform={}
    table_info=soup.findAll('table')
    for tab in table_info:

        tab=tab.findAll('tr')
        for table_row in tab:
            try:
                tab_head=table_row.find('th').text
                tab_head=tab_head.lower()
                tab_head=tab_head.split()
                tab_head=' '.join(tab_head)
                if ':' in tab_head:
                    tab_head=tab_head.replace(":","")
                if '\n' in tab_head:
                    tab_head=tab_head.replace("\n","")
                if '\t' in tab_head:
                    tab_head=tab_head.replace("\t","")
                if '\r' in tab_head:
                    tab_head=tab_head.replace("\r","")

                
                tab_data=table_row.find('td').text
                tab_inform.update({tab_head:tab_data})
            except:
                pass
    return tab_inform        

def sizes_prices(soup):
    ret_price_list=[]
    try:
        options=[]
        price_data=[]
        o_title=soup.findAll('span',{"class":"option-title"})
        price=soup.findAll('span',{"class":"option-price"})
        for i in o_title:
            i=i.text.replace('\n',"")
            i=i.split()
            i=' '.join(i)
            options.append(i)
        for p in price:
            p=p.text.replace('\t',"")
            p=p.replace('\n',"")
            p=p.split()
            p=' '.join(p)
            price_data.append(p)
        for d in range(len(price_data)):
            price_size={}
            price_size.update({"Size":options[d],"Price":price_data[d]})
            ret_price_list.append(price_size)
    except:
        price=soup.find('span',{"class":"price"}).text
        size={"Price":price}
        ret_price_list.append(size)

    return ret_price_list

def background_description(soup):
    back_knowledge={}
    back=[]
    try:

        background=soup.find('h2',text='Background').findNext('p').text
        background_next=str(soup.find('h2',text='Background').findNext('p').next_sibling.next_sibling)
        if "<p>" in background_next:
            back.append(background)
            back.append(background_next)
        else:
            back.append(background)
        back=' | '.join(back)
        back_knowledge.update({"background":back})
    except:
        pass
    return back_knowledge

# %% [markdown]
# f = open(m,"rb")
# file=f.read()
# f.close()
# file=file.splitlines()
# len(file)

# %%
#https://www.bosterbio.com/products/western-blot-reagents.html?p=2
all_urls_primary_antibody=[]
for i in range(1):
    #="https://www.bosterbio.com/products/primary-antibodies.html?p="+str(i+1)
    s="https://www.bosterbio.com/catalogsearch/result/?q=MB10"
    source=requests.get(s).text
    soup=BeautifulSoup(source,'lxml')
    links_check=soup.findAll('a',{"class":"product-item-link"})
    for lnk in links_check:
        all_urls_primary_antibody.append(lnk['href'])
all_urls_primary_antibody
# Out:
# ['https://www.bosterbio.com/psmb10-proteasome-beta-type-10-human-recombinant-protein-protp40306-boster.html',
#  'https://www.bosterbio.com/anti-psmb10-antibody-a04960-boster.html',
#  'https://www.bosterbio.com/pcr-master-mix-mb1001-boster.html',
#  'https://www.bosterbio.com/reverse-transcriptase-rt-pcr-master-mix-mb1002-boster.html',
#  'https://www.bosterbio.com/one-step-reverse-transcriptase-rt-pcr-master-mix-mb1003-boster.html',
#  'https://www.bosterbio.com/green-dye-one-step-quantitative-real-time-pcr-qrt-pcr-master-mix-mb1004-boster.html',
#  'https://www.bosterbio.com/miniprep-kit-for-plasmid-dna-extraction-and-purification-mb1005-boster.html']

# %%
len(all_urls_primary_antibody)
# Out:
# 100

# %%
empty=[]
for num,q in enumerate(all_urls_primary_antibody):
    try:
        #url1="https://www.bosterbio.com/hrp-conjugated-anti-human-igg-sabc-kit-sa2004-boster.html"
        source=requests.get(q).text
        soup=BeautifulSoup(source,'lxml')
        #url2=soup.find('a',{"class":"product-item-link"})['href']
        #source=requests.get(url2).text
        #soup=BeautifulSoup(source,'lxml')
        sizes=sizes_prices(soup)
        if len(sizes)==0:
            sizes=[]
            alter={}
            alternate_price=soup.find("span",{"class":"price"}).text
            alter.update({"Price":alternate_price})
            sizes.append(alter)
            
        tabular_data=tables(soup)
        data_pdf=pdf_sheet(soup)
        tit=pro_title(soup)
        t_i=target_info(soup)
        assay_d=assay_details(soup)
        bc=background_description(soup)
        imgg=image_details(soup)
        if len(imgg)<1:
            imgg={}
            imshow=soup.findAll('div',{"class":"carousel-item"})
            for gg,im in enumerate(imshow):
                im=im.findAll('img')
                for b in im:
                    imgg.update({"Image_"+str(gg+1):b['src']})
        pubg=publications(soup)
        intr=introduction(soup)
        para=para_data(soup)
        for size in sizes:

            if len(tit)>0:
                size.update(tit)
            size.update({"Product URL":q})
            if(len(tabular_data)>0):
                size.update(tabular_data)
            if len(data_pdf)>0:    
                size.update(data_pdf)
            if len(assay_d)>0:    
                size.update(assay_d)
            if len(bc)>0:    
                size.update(bc)
            if len(imgg)>0:    
                size.update(imgg)
            if len(t_i)>0:
                size.update(t_i)
            if len(pubg)>0:
                size.update(pubg)
            if len(intr)>0:
                size.update(intr) 
            if len(para)>0:
                size.update(para)     
            empty.append(size)    

        print("process number "+str(num)+" completed")

    except:
        continue
# Out:
# process number 0 completed
# process number 1 completed
# process number 2 completed
# process number 3 completed
# process number 4 completed
# process number 5 completed
# process number 6 completed

# %%
df=pd.DataFrame(empty)
df["sku/catalog number"].isna().sum()
#columns#df["specificity of biotin binding"].isna().sum()
#df.to_excel("sample_reagent1.xlsx",header=True,index=False)
#for i in df.columns:
    #print(i)
    #summ=df[i].isna().sum()
    #print(summ)
    #print("**********")
    #if summ>=98:
     #   df.drop([i],inplace=True,axis=1)
        
#df
# Out:
# 10

# %%
df["Size"].isna().sum()
# Out:
# 2

# %%
linkk=[]
for i in df[" Datasheet "]:
    if "https:/" in i:
        linkk.append(i)
    else:
        i="https://www.bosterbio.com"+i
        linkk.append(i)
df[" Datasheet "]=linkk
df["sku"].isna().sum()
df.drop(["product name","size","sku/catalog number"],axis=1,inplace=True)
df
# Out:
#                               Size      Price  \
# 0                      Sample: 1ug    $250.00
# 1                     Regular: 5ug    $500.00
# 2                       Bulk: 50ug  $1,344.00
# 3                     regular size    $537.00
# 4   100ug+Free Secondary Ab BA1054    $537.00
# 5   100ug+Free Secondary Ab BA1003    $537.00
# 6                 1 plate (96 well     $80.00
# 7                5 plates (96 well    $280.00
# 8                     25 reactions    $120.00
# 9                    100 reactions    $400.00
# 10                   200 reactions    $600.00
# 11                             NaN    $600.00
# 12                             NaN    $239.00
# 13                    50 Reactions     $60.00
# 14                   100 Reactions     $80.00
# 15                   250 Reactions    $180.00
#
#                                         Product Title  \
# 0   \nPSMB10 Proteasome Beta Type 10 Human Recombi...
# 1   \nPSMB10 Proteasome Beta Type 10 Human Recombi...
# 2   \nPSMB10 Proteasome Beta Type 10 Human Recombi...
# 3                             \nAnti-PSMB10 Antibody
# 4                             \nAnti-PSMB10 Antibody
# 5                             \nAnti-PSMB10 Antibody
# 6   \nPCR Master Mix, Ready To Load (96 well, 12x8...
# 7   \nPCR Master Mix, Ready To Load (96 well, 12x8...
# 8     \nReverse Transcriptase RT PCR Master Mix (5X)
# 9     \nReverse Transcriptase RT PCR Master Mix (5X)
# 10    \nReverse Transcriptase RT PCR Master Mix (5X)
# 11  \nOne Step RT PCR Kit (cDNA Synthesis + PCR In...
# 12  \nGreen Dye One Step qRT-PCR Master Mix For Qu...
# 13  \nMiniprep Kit For Plasmid DNA Extraction And ...
# 14  \nMiniprep Kit For Plasmid DNA Extraction And ...
# 15  \nMiniprep Kit For Plasmid DNA Extraction And ...
#
#                                           Product URL         sku  \
# 0   https://www.bosterbio.com/psmb10-proteasome-be...  PROTP40306
# 1   https://www.bosterbio.com/psmb10-proteasome-be...  PROTP40306
# 2   https://www.bosterbio.com/psmb10-proteasome-be...  PROTP40306
# 3   https://www.bosterbio.com/anti-psmb10-antibody...      A04960
# 4   https://www.bosterbio.com/anti-psmb10-antibody...      A04960
# 5   https://www.bosterbio.com/anti-psmb10-antibody...      A04960
# 6   https://www.bosterbio.com/pcr-master-mix-mb100...      MB1001
# 7   https://www.bosterbio.com/pcr-master-mix-mb100...      MB1001
# 8   https://www.bosterbio.com/reverse-transcriptas...      MB1002
# 9   https://www.bosterbio.com/reverse-transcriptas...      MB1002
# 10  https://www.bosterbio.com/reverse-transcriptas...      MB1002
# 11  https://www.bosterbio.com/one-step-reverse-tra...      MB1003
# 12  https://www.bosterbio.com/green-dye-one-step-q...      MB1004
# 13  https://www.bosterbio.com/miniprep-kit-for-pla...      MB1005
# 14  https://www.bosterbio.com/miniprep-kit-for-pla...      MB1005
# 15  https://www.bosterbio.com/miniprep-kit-for-pla...      MB1005
#
#     applications  source                                 storage & handling  \
# 0   Cell Culture  Rabbit  Store in -20°C for long term storage. After re...
# 1   Cell Culture  Rabbit  Store in -20°C for long term storage. After re...
# 2   Cell Culture  Rabbit  Store in -20°C for long term storage. After re...
# 3    IF, IHC, WB     NaN  At -20°C for one year. At 4°C for one month. I...
# 4    IF, IHC, WB     NaN  At -20°C for one year. At 4°C for one month. I...
# 5    IF, IHC, WB     NaN  At -20°C for one year. At 4°C for one month. I...
# 6            NaN     NaN                                                NaN
# 7            NaN     NaN                                                NaN
# 8            NaN     NaN                                                NaN
# 9            NaN     NaN                                                NaN
# 10           NaN     NaN                                                NaN
# 11           NaN     NaN                                                NaN
# 12           NaN     NaN                                                NaN
# 13           NaN     NaN                                                NaN
# 14           NaN     NaN                                                NaN
# 15           NaN     NaN                                                NaN
#
#                                           description  \
# 0   PSMB10 Human Recombinant produced in E.Coli is...
# 1   PSMB10 Human Recombinant produced in E.Coli is...
# 2   PSMB10 Human Recombinant produced in E.Coli is...
# 3   Anti-PSMB10 Antibody validated for WB, IHC, IF...
# 4   Anti-PSMB10 Antibody validated for WB, IHC, IF...
# 5   Anti-PSMB10 Antibody validated for WB, IHC, IF...
# 6   A plate of 12 individual 8-tube strips filled ...
# 7   A plate of 12 individual 8-tube strips filled ...
# 8   This Master Mix contains all reagents needed f...
# 9   This Master Mix contains all reagents needed f...
# 10  This Master Mix contains all reagents needed f...
# 11  This Kit contains all the reagents necessary f...
# 12  This Kit contains all the reagents necessary f...
# 13            Miniprep kit for plasmid DNA extraction
# 14            Miniprep kit for plasmid DNA extraction
# 15            Miniprep kit for plasmid DNA extraction
#
#                                     cite this product  ...  \
# 0   PSMB10 Proteasome Beta Type 10 Human Recombina...  ...
# 1   PSMB10 Proteasome Beta Type 10 Human Recombina...  ...
# 2   PSMB10 Proteasome Beta Type 10 Human Recombina...  ...
# 3   Anti-PSMB10 Antibody (Boster Biological Techno...  ...
# 4   Anti-PSMB10 Antibody (Boster Biological Techno...  ...
# 5   Anti-PSMB10 Antibody (Boster Biological Techno...  ...
# 6                                                 NaN  ...
# 7                                                 NaN  ...
# 8                                                 NaN  ...
# 9                                                 NaN  ...
# 10                                                NaN  ...
# 11                                                NaN  ...
# 12                                                NaN  ...
# 13                                                NaN  ...
# 14                                                NaN  ...
# 15                                                NaN  ...
#
#                                               Image_3 Image_3_description  \
# 0                                                 NaN                 NaN
# 1                                                 NaN                 NaN
# 2                                                 NaN                 NaN
# 3   https://www.bosterbio.com/media/catalog/produc...
# 4   https://www.bosterbio.com/media/catalog/produc...
# 5   https://www.bosterbio.com/media/catalog/produc...
# 6                                                 NaN                 NaN
# 7                                                 NaN                 NaN
# 8                                                 NaN                 NaN
# 9                                                 NaN                 NaN
# 10                                                NaN                 NaN
# 11                                                NaN                 NaN
# 12                                                NaN                 NaN
# 13                                                NaN                 NaN
# 14                                                NaN                 NaN
# 15                                                NaN                 NaN
#
#                                      application  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 5                                            NaN
# 6                                            PCR
# 7                                            PCR
# 8                    first‐strand cDNA synthesis
# 9                    first‐strand cDNA synthesis
# 10                   first‐strand cDNA synthesis
# 11           first‐strand cDNA synthesis and PCR
# 12  qPCR (cDNA synthesis + qPCR in one reaction)
# 13                            PCR DNA extraction
# 14                            PCR DNA extraction
# 15                            PCR DNA extraction
#
#                                          Introduction  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6   A plate of 12 individual 8-tube strips filled ...
# 7   A plate of 12 individual 8-tube strips filled ...
# 8   Boster's Reverse Transcriptase RT PCR Master M...
# 9   Boster's Reverse Transcriptase RT PCR Master M...
# 10  Boster's Reverse Transcriptase RT PCR Master M...
# 11  Boster's One Step RT PCR Kit contains all the ...
# 12  Boster's Green Dye One Step qRT-PCR Master Mix...
# 13  Boster's The EZ-Spin Column Plasmid DNA Minipr...
# 14  Boster's The EZ-Spin Column Plasmid DNA Minipr...
# 15  Boster's The EZ-Spin Column Plasmid DNA Minipr...
#
#                                          introduction  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6    <p>A plate of 12 individual 8-tube strips fil...
# 7    <p>A plate of 12 individual 8-tube strips fil...
# 8    <p>Boster's Reverse Transcriptase RT PCR Mast...
# 9    <p>Boster's Reverse Transcriptase RT PCR Mast...
# 10   <p>Boster's Reverse Transcriptase RT PCR Mast...
# 11   <p>Boster's One Step RT PCR Kit contains all ...
# 12   <p>Boster's Green Dye One Step qRT-PCR Master...
# 13   <p>Boster's The EZ-Spin Column Plasmid DNA Mi...
# 14   <p>Boster's The EZ-Spin Column Plasmid DNA Mi...
# 15   <p>Boster's The EZ-Spin Column Plasmid DNA Mi...
#
#                                               storage  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6    <p>Store the plate at room temperature for 1 ...
# 7    <p>Store the plate at room temperature for 1 ...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
#
#                                    list of components  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8    <p>Store all components at ‐20°C in a non‐def...
# 9    <p>Store all components at ‐20°C in a non‐def...
# 10   <p>Store all components at ‐20°C in a non‐def...
# 11   <p>Store all components at ‐20°C in a non‐def...
# 12   <p>Store all components at ‐20°C in a non‐def...
# 13   <p>Store all components at ‐20°C in a non‐def...
# 14   <p>Store all components at ‐20°C in a non‐def...
# 15   <p>Store all components at ‐20°C in a non‐def...
#
#                                        assay protocol  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8    <p>Reverse transcription reactions should alw...
# 9    <p>Reverse transcription reactions should alw...
# 10   <p>Reverse transcription reactions should alw...
# 11                                                NaN
# 12   <p>RT-PCR should be assembled in a nuclease-f...
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
#
#                                         general notes  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8    <p>\r\n1.\tBoth poly(A) + mRNA and total RNA ...
# 9    <p>\r\n1.\tBoth poly(A) + mRNA and total RNA ...
# 10   <p>\r\n1.\tBoth poly(A) + mRNA and total RNA ...
# 11                                                NaN
# 12   <p>\r\n1.\tAliquot reagents to avoid contamin...
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
#
#         equipment and reagents to be supplied by user
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13   <p>When working with chemicals, always wear a...
# 14   <p>When working with chemicals, always wear a...
# 15   <p>When working with chemicals, always wear a...
#
# [16 rows x 46 columns]

# %%
for i in df.columns:
    df[i]=df[i].str.replace("<p>","")
    df[i]=df[i].str.replace("</p>","|")
    df[i]=df[i].str.replace("\n","|")
df
# Out:
#                               Size      Price  \
# 0                      Sample: 1ug    $250.00
# 1                     Regular: 5ug    $500.00
# 2                       Bulk: 50ug  $1,344.00
# 3                     regular size    $537.00
# 4   100ug+Free Secondary Ab BA1054    $537.00
# 5   100ug+Free Secondary Ab BA1003    $537.00
# 6                 1 plate (96 well     $80.00
# 7                5 plates (96 well    $280.00
# 8                     25 reactions    $120.00
# 9                    100 reactions    $400.00
# 10                   200 reactions    $600.00
# 11                             NaN    $600.00
# 12                             NaN    $239.00
# 13                    50 Reactions     $60.00
# 14                   100 Reactions     $80.00
# 15                   250 Reactions    $180.00
#
#                                         Product Title  \
# 0   |PSMB10 Proteasome Beta Type 10 Human Recombin...
# 1   |PSMB10 Proteasome Beta Type 10 Human Recombin...
# 2   |PSMB10 Proteasome Beta Type 10 Human Recombin...
# 3                              |Anti-PSMB10 Antibody
# 4                              |Anti-PSMB10 Antibody
# 5                              |Anti-PSMB10 Antibody
# 6   |PCR Master Mix, Ready To Load (96 well, 12x8 ...
# 7   |PCR Master Mix, Ready To Load (96 well, 12x8 ...
# 8      |Reverse Transcriptase RT PCR Master Mix (5X)
# 9      |Reverse Transcriptase RT PCR Master Mix (5X)
# 10     |Reverse Transcriptase RT PCR Master Mix (5X)
# 11  |One Step RT PCR Kit (cDNA Synthesis + PCR In ...
# 12  |Green Dye One Step qRT-PCR Master Mix For Qua...
# 13  |Miniprep Kit For Plasmid DNA Extraction And P...
# 14  |Miniprep Kit For Plasmid DNA Extraction And P...
# 15  |Miniprep Kit For Plasmid DNA Extraction And P...
#
#                                           Product URL         sku  \
# 0   https://www.bosterbio.com/psmb10-proteasome-be...  PROTP40306
# 1   https://www.bosterbio.com/psmb10-proteasome-be...  PROTP40306
# 2   https://www.bosterbio.com/psmb10-proteasome-be...  PROTP40306
# 3   https://www.bosterbio.com/anti-psmb10-antibody...      A04960
# 4   https://www.bosterbio.com/anti-psmb10-antibody...      A04960
# 5   https://www.bosterbio.com/anti-psmb10-antibody...      A04960
# 6   https://www.bosterbio.com/pcr-master-mix-mb100...      MB1001
# 7   https://www.bosterbio.com/pcr-master-mix-mb100...      MB1001
# 8   https://www.bosterbio.com/reverse-transcriptas...      MB1002
# 9   https://www.bosterbio.com/reverse-transcriptas...      MB1002
# 10  https://www.bosterbio.com/reverse-transcriptas...      MB1002
# 11  https://www.bosterbio.com/one-step-reverse-tra...      MB1003
# 12  https://www.bosterbio.com/green-dye-one-step-q...      MB1004
# 13  https://www.bosterbio.com/miniprep-kit-for-pla...      MB1005
# 14  https://www.bosterbio.com/miniprep-kit-for-pla...      MB1005
# 15  https://www.bosterbio.com/miniprep-kit-for-pla...      MB1005
#
#     applications  source                                 storage & handling  \
# 0   Cell Culture  Rabbit  Store in -20°C for long term storage. After re...
# 1   Cell Culture  Rabbit  Store in -20°C for long term storage. After re...
# 2   Cell Culture  Rabbit  Store in -20°C for long term storage. After re...
# 3    IF, IHC, WB     NaN  At -20°C for one year. At 4°C for one month. I...
# 4    IF, IHC, WB     NaN  At -20°C for one year. At 4°C for one month. I...
# 5    IF, IHC, WB     NaN  At -20°C for one year. At 4°C for one month. I...
# 6            NaN     NaN                                                NaN
# 7            NaN     NaN                                                NaN
# 8            NaN     NaN                                                NaN
# 9            NaN     NaN                                                NaN
# 10           NaN     NaN                                                NaN
# 11           NaN     NaN                                                NaN
# 12           NaN     NaN                                                NaN
# 13           NaN     NaN                                                NaN
# 14           NaN     NaN                                                NaN
# 15           NaN     NaN                                                NaN
#
#                                           description  \
# 0   PSMB10 Human Recombinant produced in E.Coli is...
# 1   PSMB10 Human Recombinant produced in E.Coli is...
# 2   PSMB10 Human Recombinant produced in E.Coli is...
# 3   Anti-PSMB10 Antibody validated for WB, IHC, IF...
# 4   Anti-PSMB10 Antibody validated for WB, IHC, IF...
# 5   Anti-PSMB10 Antibody validated for WB, IHC, IF...
# 6   A plate of 12 individual 8-tube strips filled ...
# 7   A plate of 12 individual 8-tube strips filled ...
# 8   This Master Mix contains all reagents needed f...
# 9   This Master Mix contains all reagents needed f...
# 10  This Master Mix contains all reagents needed f...
# 11  This Kit contains all the reagents necessary f...
# 12  This Kit contains all the reagents necessary f...
# 13            Miniprep kit for plasmid DNA extraction
# 14            Miniprep kit for plasmid DNA extraction
# 15            Miniprep kit for plasmid DNA extraction
#
#                                     cite this product  ...  \
# 0   PSMB10 Proteasome Beta Type 10 Human Recombina...  ...
# 1   PSMB10 Proteasome Beta Type 10 Human Recombina...  ...
# 2   PSMB10 Proteasome Beta Type 10 Human Recombina...  ...
# 3   Anti-PSMB10 Antibody (Boster Biological Techno...  ...
# 4   Anti-PSMB10 Antibody (Boster Biological Techno...  ...
# 5   Anti-PSMB10 Antibody (Boster Biological Techno...  ...
# 6                                                 NaN  ...
# 7                                                 NaN  ...
# 8                                                 NaN  ...
# 9                                                 NaN  ...
# 10                                                NaN  ...
# 11                                                NaN  ...
# 12                                                NaN  ...
# 13                                                NaN  ...
# 14                                                NaN  ...
# 15                                                NaN  ...
#
#                                               Image_3 Image_3_description  \
# 0                                                 NaN                 NaN
# 1                                                 NaN                 NaN
# 2                                                 NaN                 NaN
# 3   https://www.bosterbio.com/media/catalog/produc...
# 4   https://www.bosterbio.com/media/catalog/produc...
# 5   https://www.bosterbio.com/media/catalog/produc...
# 6                                                 NaN                 NaN
# 7                                                 NaN                 NaN
# 8                                                 NaN                 NaN
# 9                                                 NaN                 NaN
# 10                                                NaN                 NaN
# 11                                                NaN                 NaN
# 12                                                NaN                 NaN
# 13                                                NaN                 NaN
# 14                                                NaN                 NaN
# 15                                                NaN                 NaN
#
#                                      application  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 5                                            NaN
# 6                                            PCR
# 7                                            PCR
# 8                    first‐strand cDNA synthesis
# 9                    first‐strand cDNA synthesis
# 10                   first‐strand cDNA synthesis
# 11           first‐strand cDNA synthesis and PCR
# 12  qPCR (cDNA synthesis + qPCR in one reaction)
# 13                            PCR DNA extraction
# 14                            PCR DNA extraction
# 15                            PCR DNA extraction
#
#                                          Introduction  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6   A plate of 12 individual 8-tube strips filled ...
# 7   A plate of 12 individual 8-tube strips filled ...
# 8   Boster's Reverse Transcriptase RT PCR Master M...
# 9   Boster's Reverse Transcriptase RT PCR Master M...
# 10  Boster's Reverse Transcriptase RT PCR Master M...
# 11  Boster's One Step RT PCR Kit contains all the ...
# 12  Boster's Green Dye One Step qRT-PCR Master Mix...
# 13  Boster's The EZ-Spin Column Plasmid DNA Minipr...
# 14  Boster's The EZ-Spin Column Plasmid DNA Minipr...
# 15  Boster's The EZ-Spin Column Plasmid DNA Minipr...
#
#                                          introduction  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6    A plate of 12 individual 8-tube strips filled...
# 7    A plate of 12 individual 8-tube strips filled...
# 8    Boster's Reverse Transcriptase RT PCR Master ...
# 9    Boster's Reverse Transcriptase RT PCR Master ...
# 10   Boster's Reverse Transcriptase RT PCR Master ...
# 11   Boster's One Step RT PCR Kit contains all the...
# 12   Boster's Green Dye One Step qRT-PCR Master Mi...
# 13   Boster's The EZ-Spin Column Plasmid DNA Minip...
# 14   Boster's The EZ-Spin Column Plasmid DNA Minip...
# 15   Boster's The EZ-Spin Column Plasmid DNA Minip...
#
#                                               storage  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6    Store the plate at room temperature for 1 mon...
# 7    Store the plate at room temperature for 1 mon...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
#
#                                    list of components  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8    Store all components at ‐20°C in a non‐defros...
# 9    Store all components at ‐20°C in a non‐defros...
# 10   Store all components at ‐20°C in a non‐defros...
# 11   Store all components at ‐20°C in a non‐defros...
# 12   Store all components at ‐20°C in a non‐defros...
# 13   Store all components at ‐20°C in a non‐defros...
# 14   Store all components at ‐20°C in a non‐defros...
# 15   Store all components at ‐20°C in a non‐defros...
#
#                                        assay protocol  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8    Reverse transcription reactions should always...
# 9    Reverse transcription reactions should always...
# 10   Reverse transcription reactions should always...
# 11                                                NaN
# 12   RT-PCR should be assembled in a nuclease-free...
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
#
#                                         general notes  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8    \r|1.\tBoth poly(A) + mRNA and total RNA can ...
# 9    \r|1.\tBoth poly(A) + mRNA and total RNA can ...
# 10   \r|1.\tBoth poly(A) + mRNA and total RNA can ...
# 11                                                NaN
# 12   \r|1.\tAliquot reagents to avoid contaminatio...
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
#
#         equipment and reagents to be supplied by user
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13   When working with chemicals, always wear a su...
# 14   When working with chemicals, always wear a su...
# 15   When working with chemicals, always wear a su...
#
# [16 rows x 46 columns]

# %%
#df["background"]=df["background"].str.replace("<p>","")
#df["background"]=df["background"].str.replace("</p>","")
#df["Size"].isna().sum()
#df.drop([] ,axis=1,inplace=True)
#df["specificyity"].isna().sum()
df["Image_1"]
# Out:
# 0                                                   NaN
# 1                                                   NaN
# 2     https://www.bosterbio.com/media/catalog/produc...
# 3     https://www.bosterbio.com/media/catalog/produc...
# 4     https://www.bosterbio.com/media/catalog/produc...
#                             ...
# 95    https://www.bosterbio.com/media/catalog/produc...
# 96    https://www.bosterbio.com/media/catalog/produc...
# 97    https://www.bosterbio.com/media/catalog/produc...
# 98    https://www.bosterbio.com/media/catalog/produc...
# 99    https://www.bosterbio.com/media/catalog/produc...
# Name: Image_1, Length: 100, dtype: object

# %%
#https://www.tebu-bio.com/modules/search2/?incl=1&module=search2&cat=Antibodies&subcat=Secondaries&search=&brand=220&id_q=

df.to_excel("pcr&qpcr_prodcuts.xlsx",header=True,index=False)

# %%
# Out:
# process number 0 completed
# process number 1 completed
# process number 2 completed
# process number 3 completed
# process number 4 completed
# process number 5 completed
# process number 6 completed
# process number 7 completed
# process number 8 completed
# process number 9 completed
# process number 10 completed
# process number 11 completed
# process number 12 completed
# process number 13 completed
# process number 14 completed
# process number 15 completed
# process number 16 completed
# process number 17 completed
# process number 18 completed
# process number 19 completed
# process number 20 completed
# process number 21 completed
# process number 22 completed
# process number 23 completed
# process number 24 completed
# process number 25 completed
# process number 26 completed
# process number 27 completed
# process number 28 completed
# process number 29 completed
# process number 30 completed
# process number 31 completed
# process number 32 completed
# process number 33 completed
# process number 34 completed
# process number 35 completed
# process number 36 completed
# process number 37 completed
# process number 38 completed
# process number 39 completed
# process number 40 completed
# process number 41 completed
# process number 42 completed
# process number 43 completed
# process number 44 completed
# process number 45 completed
# process number 46 completed
# process number 47 completed
# process number 48 completed
# process number 49 completed
# process number 50 completed
# process number 51 completed
# process number 52 completed
# process number 53 completed
# process number 54 completed
# process number 55 completed
# process number 56 completed
# process number 57 completed
# process number 58 completed
# process number 59 completed
# process number 60 completed
# process number 61 completed
# process number 62 completed
# process number 63 completed
# process number 64 completed
# process number 65 completed
# process number 66 completed
# process number 67 completed
# process number 68 completed
# process number 69 completed
# process number 70 completed
# process number 71 completed
# process number 72 completed
# process number 73 completed
# process number 74 completed
# process number 75 completed
# process number 76 completed
# process number 77 completed
# process number 78 completed
# process number 79 completed
# process number 80 completed
# process number 81 completed
# process number 82 completed
# process number 83 completed
# process number 84 completed
# process number 85 completed
# process number 86 completed
# process number 87 completed
# process number 88 completed
# process number 89 completed
# process number 90 completed
# process number 91 completed
# process number 92 completed
# process number 93 completed
# process number 94 completed
# process number 95 completed
# process number 96 completed
# process number 97 completed
# process number 98 completed
# process number 99 completed
# process number 100 completed
# process number 101 completed
# process number 102 completed
# process number 103 completed
# process number 104 completed
# process number 105 completed
# process number 106 completed
# process number 107 completed
# process number 108 completed
# process number 109 completed
# process number 110 completed
# process number 111 completed
# process number 112 completed
# process number 113 completed
# process number 114 completed
# process number 115 completed
# process number 116 completed
# process number 117 completed
# process number 118 completed
# process number 119 completed
# process number 120 completed
# process number 121 completed
# process number 122 completed
# process number 123 completed
# process number 124 completed
# process number 125 completed
# process number 126 completed
# process number 127 completed
# process number 128 completed
# process number 129 completed
# process number 130 completed
# process number 131 completed
# process number 132 completed
# process number 133 completed
# process number 134 completed
# process number 135 completed
# process number 136 completed
# process number 137 completed
# process number 138 completed
# process number 139 completed
# process number 140 completed
# process number 141 completed
# process number 142 completed
# process number 143 completed
# process number 144 completed
# process number 145 completed
# process number 146 completed
# process number 147 completed
# process number 148 completed
# process number 149 completed
# process number 150 completed
# process number 151 completed
# process number 152 completed
# process number 153 completed
# process number 154 completed
# process number 155 completed
# process number 156 completed
# process number 157 completed
# process number 158 completed
# process number 159 completed
# process number 160 completed
# process number 161 completed
# process number 162 completed
# process number 163 completed
# process number 164 completed
# process number 165 completed
# process number 166 completed
# process number 167 completed
# process number 168 completed
# process number 169 completed
# process number 170 completed
# process number 171 completed
# process number 172 completed
# process number 173 completed
# [{'Price': '$120.00',
#   'Product Title': '\n10nm Colloidal Gold Labeled Secondary Antibody, Goat Anti-Mouse IgG (H+L) ',
#   'Product URL': 'https://www.bosterbio.com/10-nm-colloidal-gold-conjugated-goat-anti-mouse-igg-secondary-antibody-ga1004-boster.html',
#   'SKU': 'GA1004',
#   'Pack size ': '1 ml',
#   'Applications': '\tEM, IHC-P, IHC-F, ICC',
#   'Product Name': 'Goat Anti-Mouse IgG (H+L) Secondary Antibody, 10 nm Colloidal Gold Conjugate',
#   'Synonyms': '10 nm Colloidal Gold Labeled Secondary Antibody, Goat Anti-Mouse IgG; 10 nm Colloidal Gold Conjugated Goat Anti-Mouse IgG; Goat Anti-Mouse IgG 10 nm Colloidal Gold Secondary Antibody',
#   'Description': 'Goat Anti-mouse IgG (H+L) secondary antibody, 10 nm Colloidal Gold Conjugate, for detection, localization, distribution and quantification of target proteins at an ultrastructural level via indirect immunogold staining in IHC-P, IHC-F, ICC, or EM.',
#   'Reagent Type': 'Colloidal gold conjugated secondary antibody',
#   'Conjugate': 'Colloidal gold, 10 nm',
#   'Host': 'Goat',
#   'Target Species': 'Rabbit',
#   'Antibody Class': 'IgG',
#   'Clonality': 'Polyclonal',
#   'Immunogen': 'Whole molecule mouse IgG',
#   'Purification': 'Immunoaffinity chromatography, solid phase adsorbed with human serum proteins',
#   'Specificity': 'Rabbit IgG specific: no cross-reactivity with mouse/bovine IgG',
#   'Form Supplied': 'Liquid: concentrated buffered stock solution',
#   'Formulation': '0.5 mg colloidal gold-conjugated secondary antibody\r\n\t\t\t0.01 M PBS (PH 7.4)\r\n\t\t\t0.01% Thimerosal\r\n\t\t\t50% glycerol',
#   'Pack Size': '1 ml',
#   'Concentration': '0.1 mg/ml',
#   'Application': 'Electron Microscopy, IHC-P, IHC-F, ICC',
#   'Storage': '4C for 1 year',
#   'Precautions': 'FOR RESEARCH USE ONLY. NOT FOR DIAGNOSTIC OR CLINICAL USE',
#   'Sample Type': 'Rabbit primary-antibody-probed ultrathin sliced formalin-fixed paraffin-embedded (FFPE) tissue sections(IHC-P), ultrathin thawed frozen sections(IHC-F), cultured cells',
#   'Assay Type': 'Immunoanalytical',
#   'Technique': 'Indirect immunodetection of target protein via reporter-labeled biotin-binding detection systems',
#   'Assay Purpose': 'Protein detection/quantification',
#   'Equipment Needed': 'Light microscope, scanning electron microscope or transmission electron microscope, micrograph or scan',
#   'Specific': 'High signal-to-noise ratio',
#   'High Signal Amplification': 'Multiple secondary antibodies can bind to a single primary antibody; label size is larger than tissue structures; much more intense stain than conventional HRP and PAP techniques; additional silver enhancement can be applied',
#   'Fast': 'Fewer processing steps - no need to add a substrate; Less optimization required compared to enzymatic detection; Generates strong signals in a relatively short time span; signal can be observed directly',
#   'Quantifieable': 'The digital nature of the gold signal + high precision in allocating gold labels to defined structures makes it easy to count and quantify',
#   'Easy to Use': 'Supplied in a workable liquid format ',
#   'Flexible': 'Diversity of non-overlapping particle sizes for labeling at different working magnifications, suitable for single or multi-label detection, may be used as a probe in immunoblotting, light microscopy, fluorescence microscopy or electron microscopy, ability to label sections from the same block for both light and electron microscopy, can be used to localize certain antigens in sectioned tissue or cultured cells, excellent labelling in wax, resin embedded or frozen sections, a variety of tissue stains can be used to counterstain the dense black reaction product after silver enhancement',
#   'Stability': 'Gold particles bind proteins rapidly and stably -  permanent label, no fading, macromolecule localization and distribution can be recorded using specialized photography',
#   ' Datasheet ': '/media/pdf/GA1004_DS.pdf',
#   ' Protocols ': 'https://www.bosterbio.com/protocol-and-troubleshooting/',
#   'Background': 'Most commonly, secondary antibodies are generated by immunizing the host animal with a pooled population of immunoglobulins from the target species. The host antiserum is then purified through immunoaffinity chromatography to remove all host serum proteins, except the specific antibody of interest, and then modified with antibody fragmentation, label conjugation, etc., to generate highly specific detection reagents. Secondary antibodies can be conjugated to a large number of labels, including enzymes, biotin, fluorescent dyes/proteins, or gold particles. Here, the antibody provides the specificity to locate the protein of interest by recognizing a primary antibody that targets a particular antigen, and the label generates a detectable signal in the area of the formed immune complexes. The label of choice depends upon the experimental application. | <p>Immunolabeling with gold particles—also known as immunogold labeling, immunogold staining, or immunocolloidal gold technique—is a technique that uses colloidal gold as a marker. Colloidal gold is a negatively charged hydrophobic suspension, formed by electron dense metallic particles which have large specific surface area. It binds to macromolecules (IgG, Protein A or G) rapidly and stably by noncovalent electrostatic adsorption, preserving their natural biological activity. It has been used as a marker particle for the past 2 decades because of its simplicity of preparation, high resolution, good biocompatibility and tissue penetration and hence its suitability for ultrastructural studies and quantitative immunostaining. Due to variability in particle sizes and its high electron density, immunocolloidal gold technique is suitable for single or multi-label detection under immune-electron microscopes as well as light microscopes. It is used regularly with scanning electron microscopy (SEM) and transmission electron microscopy (TEM) to successfully identify the areas within cells and tissues where antigens are located. The high resolution of the technique allows to study structure–function relationships in the microenvironment of cells and tissues, and also explore protein distribution in cellular and extracellular components. Smaller gold particles are found to produce higher labeling intensity of the target antigen because of reduced steric hindrance. However, if steric hindrance does not make a significant difference, then larger gold particles could produce stronger color intensity under the light microscope. When smaller gold particles (1-5 nm) are used, the visualization is usually improved using silver-enhancement methods. Gold can also be attached to protein A or protein G instead of a secondary antibody, as these proteins bind mammalian IgG Fc regions in a non-specific way.\r\n</p>'},
#  {'Price': '$120.00',
#   'Product Title': '\n10nm Colloidal Gold Labeled Secondary Antibody, Goat Anti-Rabbit IgG (H+L) ',
#   'Product URL': 'https://www.bosterbio.com/10-nm-colloidal-gold-conjugated-goat-anti-rabbit-igg-secondary-antibody-ga1014-boster.html',
#   'SKU': 'GA1014',
#   'Pack size ': '1 ml',
#   'Applications': 'EM, IHC-P, IHC-F, ICC',
#   'Product Name': 'Goat Anti-Rabbit IgG (H+L) Secondary Antibody, 10 nm Colloidal Gold Conjugate',
#   'Synonyms': '10 nm Colloidal Gold Labeled Secondary Antibody, Goat Anti-Rabbit IgG; 10 nm Colloidal Gold Conjugated Goat Anti-Rabbit IgG; Goat Anti-Rabbit IgG 10 nm Colloidal Gold Secondary Antibody',
#   'Description': 'Goat Anti-rabbit IgG (H+L) secondary antibody, 10 nm Colloidal Gold Conjugate, for detection, localization, distribution and quantification of target proteins at an ultrastructural level via indirect immunogold staining in IHC-P, IHC-F, ICC, or EM.',
#   'Reagent Type': 'Colloidal gold conjugated secondary antibody',
#   'Conjugate': 'Colloidal gold, 10 nm',
#   'Host': 'Goat',
#   'Target Species': 'Rabbit',
#   'Antibody Class': 'IgG',
#   'Clonality': 'Polyclonal',
#   'Immunogen': 'Whole molecule rabbit IgG',
#   'Purification': 'Immunoaffinity chromatography, solid phase adsorbed with human serum proteins',
#   'Specificity': 'Rabbit IgG specific: no cross-reactivity with mouse/bovine IgG',
#   'Form Supplied': 'Liquid: concentrated buffered stock solution',
#   'Formulation': '0.5 mg colloidal gold-conjugated secondary antibody\r\n\t\t\t0.01 M PBS (PH 7.4)\r\n\t\t\t0.01% Thimerosal\r\n\t\t\t50% glycerol',
#   'Pack Size': '1 ml',
#   'Concentration': '0.1 mg/ml',
#   'Application': 'Electron Microscopy, IHC-P, IHC-F, ICC',
#   'Storage': '4C for 1 year',
#   'Precautions': 'FOR RESEARCH USE ONLY. NOT FOR DIAGNOSTIC OR CLINICAL USE',
#   'Sample Type': 'Goat primary-antibody-probed ultrathin sliced formalin-fixed paraffin-embedded (FFPE) tissue sections(IHC-P), ultrathin thawed frozen sections(IHC-F), cultured cells',
#   'Assay Type': 'Immunoanalytical',
#   'Technique': 'Indirect immunodetection of target protein via reporter-labeled biotin-binding detection systems',
#   'Assay Purpose': 'Protein detection/quantification',
#   'Equipment Needed': 'Light microscope, scanning electron microscope or transmission electron microscope, micrograph or scan',
#   'Specific': 'High signal-to-noise ratio',
#   'High Signal Amplification': 'Multiple secondary antibodies can bind to a single primary antibody; label size is larger than tissue structures; much more intense stain than conventional HRP and PAP techniques; additional silver enhancement can be applied',
#   'Fast': 'Fewer processing steps - no need to add a substrate; Less optimization required compared to enzymatic detection; Generates strong signals in a relatively short time span; signal can be observed directly',
#   'Quantifieable': 'The digital nature of the gold signal + high precision in allocating gold labels to defined structures makes it easy to count and quantify',
#   'Easy to Use': 'Supplied in a workable liquid format ',
#   'Flexible': 'Diversity of non-overlapping particle sizes for labeling at different working magnifications, suitable for single or multi-label detection, may be used as a probe in immunoblotting, light microscopy, fluorescence microscopy or electron microscopy, ability to label sections from the same block for both light and electron microscopy, can be used to localize certain antigens in sectioned tissue or cultured cells, excellent labelling in wax, resin embedded or frozen sections, a variety of tissue stains can be used to counterstain the dense black reaction product after silver enhancement',
#   'Stability': 'Gold particles bind proteins rapidly and stably -  permanent label, no fading, macromolecule localization and distribution can be recorded using specialized photography',
#   ' Datasheet ': '/media/pdf/GA1014_DS.pdf',
#   ' Protocols ': 'https://www.bosterbio.com/protocol-and-troubleshooting/',
#   'Background': 'Most commonly, secondary antibodies are generated by immunizing the host animal with a pooled population of immunoglobulins from the target species. The host antiserum is then purified through immunoaffinity chromatography to remove all host serum proteins, except the specific antibody of interest, and then modified with antibody fragmentation, label conjugation, etc., to generate highly specific detection reagents. Secondary antibodies can be conjugated to a large number of labels, including enzymes, biotin, fluorescent dyes/proteins, or gold particles. Here, the antibody provides the specificity to locate the protein of interest by recognizing a primary antibody that targets a particular antigen, and the label generates a detectable signal in the area of the formed immune complexes. The label of choice depends upon the experimental application. | <p>Immunolabeling with gold particles—also known as immunogold labeling, immunogold staining, or immunocolloidal gold technique—is a technique that uses colloidal gold as a marker. Colloidal gold is a negatively charged hydrophobic suspension, formed by electron dense metallic particles which have large specific surface area. It binds to macromolecules (IgG, Protein A or G) rapidly and stably by noncovalent electrostatic adsorption, preserving their natural biological activity. It has been used as a marker particle for the past 2 decades because of its simplicity of preparation, high resolution, good biocompatibility and tissue penetration and hence its suitability for ultrastructural studies and quantitative immunostaining. Due to variability in particle sizes and its high electron density, immunocolloidal gold technique is suitable for single or multi-label detection under immune-electron microscopes as well as light microscopes. It is used regularly with scanning electron microscopy (SEM) and transmission electron microscopy (TEM) to successfully identify the areas within cells and tissues where antigens are located. The high resolution of the technique allows to study structure–function relationships in the microenvironment of cells and tissues, and also explore protein distribution in cellular and extracellular components. Smaller gold particles are found to produce higher labeling intensity of the target antigen because of reduced steric hindrance. However, if steric hindrance does not make a significant difference, then larger gold particles could produce stronger color intensity under the light microscope. When smaller gold particles (1-5 nm) are used, the visualization is usually improved using silver-enhancement methods. Gold can also be attached to protein A or protein G instead of a secondary antibody, as these proteins bind mammalian IgG Fc regions in a non-specific way.\r\n</p>'},
#  {'Price': '$120.00',
#   'Product Title': '\n5nm Colloidal Gold Labeled Secondary Antibody, Goat Anti-Mouse IgG (H+L) ',
#   'Product URL': 'https://www.bosterbio.com/5-nm-colloidal-gold-conjugated-goat-anti-mouse-igg-secondary-antibody-ga1003-boster.html',
#   'SKU:': 'GA1003',
#   'Pack Size:': '1ml',
#   'Validated Species:': 'Mouse',
#   'Host:': 'Goat',
#   'Clonality:': 'Polyclonal',
#   'Application:': 'EM, IHC, ICC',
#   ' Datasheet ': '/media/pdf/GA1003_DS.pdf',
#   ' Protocols ': 'https://www.bosterbio.com/protocol-and-troubleshooting/'},
#  {'Price': '$120.00',
#   'Product Title': '\n5nm Colloidal Gold Labeled Secondary Antibody, Goat Anti-Rabbit IgG (H+L) ',
#   'Product URL': 'https://www.bosterbio.com/5-nm-colloidal-gold-conjugated-goat-anti-rabbit-igg-secondary-antibody-ga1013-boster.html',
#   'SKU': 'GA1013',
#   'Pack size ': '1 ml',
#   'Applications': 'EM, IHC-P, IHC-F, ICC',
#   'Product Name': 'Goat Anti-Rabbit IgG (H+L) Secondary Antibody, 5 nm Colloidal Gold Conjugate',
#   'Synonyms': '5 nm Colloidal Gold Labeled Secondary Antibody, Goat Anti-Rabbit IgG; 5 nm Colloidal Gold Conjugated Goat Anti-Rabbit IgG; Goat Anti-Rabbit IgG 5 nm Colloidal Gold Secondary Antibody',
#   'Description': 'Goat Anti-rabbit IgG (H+L) secondary antibody, 5 nm Colloidal Gold Conjugate, for detection, localization, distribution and quantification of target proteins at an ultrastructural level via indirect immunogold staining in IHC-P, IHC-F, ICC, or EM.',
#   'Reagent Type': 'Colloidal gold conjugated secondary antibody',
#   'Conjugate': 'Colloidal gold, 5 nm',
#   'Host': 'Goat',
#   'Target Species': 'Rabbit',
#   'Antibody Class': 'IgG',
#   'Clonality': 'Polyclonal',
#   'Immunogen': 'Whole molecule rabbit IgG',
#   'Purification': 'Immunoaffinity chromatography',
#   'Specificity': 'Rabbit IgG specific: no cross-reactivity with mouse/bovine IgG',
#   'Form Supplied': 'Liquid: concentrated buffered stock solution',
#   'Formulation': '0.5 mg colloidal gold-conjugated secondary antibody\r\n\t\t\t0.01 M PBS (PH 7.4)\r\n\t\t\t0.01% Thimerosal\r\n\t\t\t50% glycerol',
#   'Pack Size': '1 ml',
#   'Concentration': '0.1 mg/ml',
#   'Application': 'Electron Microscopy, IHC-P, IHC-F, ICC',
#   'Storage': '4C for 1 year',
#   'Precautions': 'FOR RESEARCH USE ONLY. NOT FOR DIAGNOSTIC OR CLINICAL USE',
#   'Sample Type': 'Rabbit primary-antibody-probed ultrathin sliced formalin-fixed paraffin-embedded (FFPE) tissue sections(IHC-P), ultrathin thawed frozen sections(IHC-F), cultured cells',
#   'Assay Type': 'Immunoanalytical',
#   'Technique': 'Indirect immunodetection of target protein via reporter-labeled biotin-binding detection systems',
#   'Assay Purpose': 'Protein detection/quantification',
#   'Equipment Needed': 'Light microscope, scanning electron microscope or transmission electron microscope, micrograph or scan',
#   'Specific': 'High signal-to-noise ratio',
#   'High Signal Amplification': 'Multiple secondary antibodies can bind to a single primary antibody; label size is larger than tissue structures; much more intense stain than conventional HRP and PAP techniques; additional silver enhancement can be applied',
#   'Fast': 'Fewer processing steps - no need to add a substrate; Less optimization required compared to enzymatic detection; Generates strong signals in a relatively short time span; signal can be observed directly',
#   'Quantifieable': 'The digital nature of the gold signal + high precision in allocating gold labels to defined structures makes it easy to count and quantify',
#   'Easy to Use': 'Supplied in a workable liquid format ',
#   'Flexible': 'Diversity of non-overlapping particle sizes for labeling at different working magnifications, suitable for single or multi-label detection, may be used as a probe in immunoblotting, light microscopy, fluorescence microscopy or electron microscopy, ability to label sections from the same block for both light and electron microscopy, can be used to localize certain antigens in sectioned tissue or cultured cells, excellent labelling in wax, resin embedded or frozen sections, a variety of tissue stains can be used to counterstain the dense black reaction product after silver enhancement',
#   'Stability': 'Gold particles bind proteins rapidly and stably -  permanent label, no fading, macromolecule localization and distribution can be recorded using specialized photography',
#   '\tApplications\t': '\tElectron Microscopy\t',
#   '\tSample\t': '\tOyster Visceral Mass\t',
#   '\tDetection\t': '\t5nm Colloidal Gold\t\t',
#   ' Datasheet ': '/media/pdf/GA1013_DS.pdf',
#   ' Protocols ': 'https://www.bosterbio.com/protocol-and-troubleshooting/',
#   'Background': 'Most commonly, secondary antibodies are generated by immunizing the host animal with a pooled population of immunoglobulins from the target species. The host antiserum is then purified through immunoaffinity chromatography to remove all host serum proteins, except the specific antibody of interest, and then modified with antibody fragmentation, label conjugation, etc., to generate highly specific detection reagents. Secondary antibodies can be conjugated to a large number of labels, including enzymes, biotin, fluorescent dyes/proteins, or gold particles. Here, the antibody provides the specificity to locate the protein of interest by recognizing a primary antibody that targets a particular antigen, and the label generates a detectable signal in the area of the formed immune complexes. The label of choice depends upon the experimental application. | <p>Immunolabeling with gold particles—also known as immunogold labeling, immunogold staining, or immunocolloidal gold technique—is a technique that uses colloidal gold as a marker. Colloidal gold is a negatively charged hydrophobic suspension, formed by electron dense metallic particles which have large specific surface area. It binds to macromolecules (IgG, Protein A or G) rapidly and stably by noncovalent electrostatic adsorption, preserving their natural biological activity. It has been used as a marker particle for the past 2 decades because of its simplicity of preparation, high resolution, good biocompatibility and tissue penetration and hence its suitability for ultrastructural studies and quantitative immunostaining. Due to variability in particle sizes and its high electron density, immunocolloidal gold technique is suitable for single or multi-label detection under immune-electron microscopes as well as light microscopes. It is used regularly with scanning electron microscopy (SEM) and transmission electron microscopy (TEM) to successfully identify the areas within cells and tissues where antigens are located. The high resolution of the technique allows to study structure–function relationships in the microenvironment of cells and tissues, and also explore protein distribution in cellular and extracellular components. Smaller gold particles are found to produce higher labeling intensity of the target antigen because of reduced steric hindrance. However, if steric hindrance does not make a significant difference, then larger gold particles could produce stronger color intensity under the light microscope. When smaller gold particles (1-5 nm) are used, the visualization is usually improved using silver-enhancement methods. Gold can also be attached to protein A or protein G instead of a secondary antibody, as these proteins bind mammalian IgG Fc regions in a non-specific way.\r\n</p>'},
#  {'Price': '$100.00',
#   'Product Title': '\nMouse Anti-Human IgG (H+L) Secondary Antibody, Biotin Conjugate ',
#   'Product URL': 'https://www.bosterbio.com/biotin-conjugated-mouse-anti-human-igg-secondary-antibody-bm2001-boster.html',
#   'SKU': 'BM2001',
#   'Pack size ': '0.5 ml',
#   'Applications': 'ELISA, IHC-P, IHC-F, ICC, WB',
#   'Product Name': 'Mouse Anti-Human IgG (H+L) Secondary Antibody, Biotin Conjugate',
#   'Synonyms': 'Biotin-conjugated Mouse Anti-Human IgG; Mouse Anti-Human IgG Biotinylated Antibody; Biotinylated Mouse Anti-Human IgG Secondary Antibody; Mouse Anti-Human IgG Secondary Antibody, Biotin-labeled',
#   'Description': 'Mouse Anti-Human IgG (H+L) Secondary Antibody, Biotin Conjugate, for indirect sensitive immunodetection and/or quantification of low-abundance target proteins through ELISA, IHC-P, IHC-F, ICC, or WB by using reporter-labeled biotin-binding signal amplification systems.',
#   'Reagent Type': 'Biotin conjugated secondary antibody',
#   'Label': 'Biotin',
#   'Host': 'Mouse',
#   'Target Species': 'Human',
#   'Antibody Class': 'IgG',
#   'Clonality': 'Polyclonal',
#   'Immunogen': 'Whole molecule human IgG',
#   'Purification': 'Immunoaffinity chromatography',
#   'Specificity': 'Human IgG specific; no cross-reactivity with rabbit/goat/bovine IgG',
#   'Form Supplied': 'Liquid: concentrated buffered stock solution',
#   'Formulation': '0.5 mg biotin-conjugated secondary antibody\r\n\t\t\t0.01 M PBS (PH 7.4)\r\n\t\t\t0.01% Thimerosal\r\n\t\t\t50% glycerol',
#   'Pack Size': '0.5 ml',
#   'Concentration': '1 mg/ml',
#   'Application': 'ELISA, IHC-P, IHC-F, ICC, WB',
#   'Storage': '4C for 1 year',
#   'Precautions': 'FOR RESEARCH USE ONLY. NOT FOR DIAGNOSTIC OR CLINICAL USE',
#   'Sample Type': 'Human primary-antibody-probed: SDS-PAGE separated-, membrane-immobilized-proteins from cell/tissue lysates, formalin-fixed paraffin-embedded (FFPE) tissue sections on slides',
#   'Assay Type': 'Immunoanalytical',
#   'Technique': 'Indirect immunodetection of target protein via reporter-labeled biotin-binding detection systems',
#   'Assay Purpose': 'Protein detection/quantification',
#   'Equipment Needed': 'WB/Dot blot/ELISA/IHC instrumentation; Reporter signal detectors: X-ray film cassette; a charge-coupled device (CCD) imager; Spectrophotometer; fluorescent or electron microscope',
#   'Specific': 'High signal-to-noise ratio',
#   'High Signal Amplification': 'Multiple secondary antibodies can bind to a single primary antibody; Multiple reporter molecules localize to a single biotin via avidin/streptavidin bridges',
#   'Fast': 'Fewer processing steps - no need to add a substrate; Less optimization required compared to enzymatic detection; Generates strong signals in a relatively short time span; Fluorescence can be observed directly',
#   'Quantifieable': 'Allows quantification of detected signal',
#   'Easy to Use': 'Supplied in a workable liquid format ',
#   'Flexible': 'Biotin-(Strept)Avidin system can be coupled with various types of reporters (enzymes, fluorochromes, fluorophores, chromophores, etc.); One type of labeled secondary antibody can be used to recognize different types of primary antibodies of the target organism specific to a particular antigen',
#   'Compatible': 'Biotin does not interfere with catalysis or antibody binding',
#   ' Datasheet ': '/media/pdf/BM2001_DS.pdf',
#   ' Protocols ': 'https://www.bosterbio.com/protocol-and-troubleshooting/',
#   'Background': 'Most commonly, secondary antibodies are generated by immunizing the host animal with a pooled population of immunoglobulins from the target species. The host antiserum is then purified through immunoaffinity chromatography to remove all host serum proteins, except the specific antibody of interest. Purified secondary antibodies are further solid phase adsorbed with other species serum proteins to minimize cross-reactivity in tissue or cell preparations, and are then modified with antibody fragmentation, label conjugation, etc., to generate highly specific reagents. Secondary antibodies can be conjugated to a large number of labels, including enzymes, biotin, and fluorescent dyes/proteins. Here, the antibody provides the specificity to locate the protein of interest, and the label generates a detectable signal. The label of choice depends upon the experimental application. | <p>Biotinylated antibodies are widely used in systems where signal amplification is desired. Often 15-20 biotin moieties are coupled to a single IgG secondary antibody. Biotin binds avidin, streptavidin, or neutravidin with a high degree of affinity and specificity. In immunoassays avidin/streptavidin-biotin binding is used as a bridge between antibodies and reporters like enzymes (HRP, AP), fluorophores, chromophores, etc. Both avidin and streptavidin are tetrameric proteins capable of binding 4 biotin groups to each molecule of avidin or streptavidin, thus amplifying the signal intensity and detection sensitivity by increasing the concentration of reporters  at the antigenic site. Two main biotin-binding detection systems have been widely utilized: Avidin-Biotin Complex (ABC) and Labeled Streptavidin Biotin (LSAB) methods. In the ABC method free avidin (or streptavidin) is used as a bridge/link between the biotinylated antibody and а biotinylated reporter molecule, resulting in three reporter molecules coupled to the biotinylated antibody. The LSAB method employs a reporter-labeled streptavidin (avidin or neutravidin can alternatively be used) to detect the bound biotinylated-secondary antibody on the tissue section, blotting membrane or ELISA plate, improving the sensitivity of detection by 8-fold. The LSAB method is used when the avidin-biotin-enzyme complex in the ABC method becomes too large to penetrate the tissue.\r\n</p>'},
#  {'Price': '$130.00',
#   'Product Title': '\nMouse Anti-Human IgG (H+L) Secondary Antibody, FITC Conjugate ',
#   'Product URL': 'https://www.bosterbio.com/fitc-conjugated-mouse-anti-human-igg-secondary-antibody-bm2003-boster.html',
#   'SKU': 'BM2003',
#   'Size': '0.5ml',
#   'Reactivity': 'Human',
#   'Clonality': 'Polyclonal',
#   'Applications': 'Flow Cytometry, IHC, ICC',
#   'Product Name': 'Mouse Anti-Human IgG (H+L) Secondary Antibody, FITC Conjugate                                            ',
#   'SKU/Catalog Number': 'BM2003',
#   'Description': 'FITC Conjugated Mouse Anti-human IgG (H+L) secondary antibody This FITC conjugated antibody is specific for human IgG and shows no cross-reactivity with rabbit/goat/bovine IgG.',
#   'Cite This Product': 'Mouse Anti-Human IgG (H+L) Secondary Antibody, FITC Conjugate (Boster Biological Technology, Pleasanton CA, USA, Catalog # BM2003)',
#   'Specificity': 'Mouse Anti-Human IgG (H+L) Secondary Antibody, FITC Conjugate (BM2003) reacts with Human , in native form and recombinant. Superfamily members of  are not reactive to BM2003.',
#   'Research Areas': 'Human*You can search these to find other products in these research areas.',
#   ' Datasheet ': '/media/pdf/BM2003_DS.pdf',
#   ' Protocols ': 'https://www.bosterbio.com/protocol-and-troubleshooting/',
#   'Assay Details': 'Our Boster Quality Guarantee for Mouse Anti-Human IgG (H+L) Secondary Antibody, FITC Conjugate covers its use in the following applications. | *The recommended dilution ratios/concentrations are for reference only and optimal dilutions/concentrations should be determined by the end user. | Boster Kit Box',
#   'Target Info': '*if product is indicated to react with multiple species, protein info is based on the human gene.'},
#  {'Price': '$45.00',
#   'Product Title': '\nRabbit Anti-Human IgG (H+L) Secondary Antibody, Biotin Conjugate ',
#   'Product URL': 'https://www.bosterbio.com/biotin-conjugated-rabbit-anti-human-igg-secondary-antibody-ba1020-boster.html',
#   'SKU': 'BA1020',
#   'Pack size ': '0.5 ml',
#   'Applications': 'ELISA, IHC-P, IHC-F, ICC, WB',
#   'Product Name': 'Rabbit Anti-Human IgG (H+L) Secondary Antibody, Biotin Conjugate',
#   'Synonyms': 'Biotin-conjugated Rabbit Anti-Human IgG; Rabbit Anti-Human IgG Biotinylated Antibody; Biotinylated Rabbit Anti-Human IgG Secondary Antibody; Rabbit Anti-Human IgG Secondary Antibody, Biotin-labeled',
#   'Description': 'Rabbit Anti-Human IgG (H+L) Secondary Antibody, Biotin Conjugate, for indirect sensitive immunodetection and/or quantification of low-abundance target proteins through ELISA, IHC-P, IHC-F, ICC, or WB by using reporter-labeled biotin-binding signal amplification systems.',
#   'Reagent Type': 'Biotin conjugated secondary antibody',
#   'Conjugate': 'Biotin',
#   'Host': 'Rabbit',
#   'Target Species': 'Human',
#   'Antibody Class': 'IgG',
#   'Clonality': 'Polyclonal',
#   'Immunogen': 'Whole molecule human IgG',
#   'Purification': 'Immunoaffinity chromatography',
#   'Specificity': 'Human IgG specific; no cross-reactivity with rat/mouse/goat/rabbit IgG',
#   'Form Supplied': 'Liquid: concentrated buffered stock solution',
#   'Formulation': '0.5 mg biotin-conjugated secondary antibody\r\n\t\t\t0.01 M PBS (PH 7.4)\r\n\t\t\t0.01% Thimerosal\r\n\t\t\t50% glycerol',
#   'Pack Size': '0.5 ml',
#   'Concentration': '1 mg/ml',
#   'Application': 'ELISA, IHC-P, IHC-F, ICC, WB',
#   'Storage': '4C for 1 year',
#   'Precautions': 'FOR RESEARCH USE ONLY. NOT FOR DIAGNOSTIC OR CLINICAL USE',
#   'Sample Type': 'Human primary-antibody-probed: SDS-PAGE separated-, membrane-immobilized-proteins from cell/tissue lysates, formalin-fixed paraffin-embedded (FFPE) tissue sections on slides',
#   'Assay Type': 'Immunoanalytical',
#   'Technique': 'Indirect immunodetection of target protein via reporter-labeled biotin-binding detection systems',
#   'Assay Purpose': 'Protein detection/quantification',
#   'Equipment Needed': 'WB/Dot blot/ELISA/IHC instrumentation; Reporter signal detectors: X-ray film cassette; a charge-coupled device (CCD) imager; Spectrophotometer; fluorescent or electron microscope',
#   'Specific': 'High signal-to-noise ratio',
#   'High Signal Amplification': 'Multiple secondary antibodies can bind to a single primary antibody; Multiple reporter molecules localize to a single biotin via avidin/streptavidin bridges',
#   'Fast': 'Fewer processing steps - no need to add a substrate; Less optimization required compared to enzymatic detection; Generates strong signals in a relatively short time span; Fluorescence can be observed directly',
#   'Quantifieable': 'Allows quantification of detected signal',
#   'Easy to Use': 'Supplied in a workable liquid format ',
#   'Flexible': 'Biotin-(Strept)Avidin system can be coupled with various types of reporters (enzymes, fluorochromes, fluorophores, chromophores, etc.); One type of labeled secondary antibody can be used to recognize different types of primary antibodies of the target organism specific to a particular antigen',
#   'Compatible': 'Biotin does not interfere with catalysis or antibody binding',
#   ' Datasheet ': '/media/pdf/BA1020_DS.pdf',
#   ' Protocols ': 'https://www.bosterbio.com/protocol-and-troubleshooting/',
#   'Background': 'Most commonly, secondary antibodies are generated by immunizing the host animal with a pooled population of immunoglobulins from the target species. The host antiserum is then purified through immunoaffinity chromatography to remove all host serum proteins, except the specific antibody of interest. Purified secondary antibodies are further solid phase adsorbed with other species serum proteins to minimize cross-reactivity in tissue or cell preparations, and are then modified with antibody fragmentation, label conjugation, etc., to generate highly specific reagents. Secondary antibodies can be conjugated to a large number of labels, including enzymes, biotin, and fluorescent dyes/proteins. Here, the antibody provides the specificity to locate the protein of interest, and the label generates a detectable signal. The label of choice depends upon the experimental application. | <p>Biotinylated antibodies are widely used in systems where signal amplification is desired. Often 15-20 biotin moieties are coupled to a single IgG secondary antibody. Biotin binds avidin, streptavidin, or neutravidin with a high degree of affinity and specificity. In immunoassays avidin/streptavidin-biotin binding is used as a bridge between antibodies and reporters like enzymes (HRP, AP), fluorophores, chromophores, etc. Both avidin and streptavidin are tetrameric proteins capable of binding 4 biotin groups to each molecule of avidin or streptavidin, thus amplifying the signal intensity and detection sensitivity by increasing the concentration of reporters  at the antigenic site. Two main biotin-binding detection systems have been widely utilized: Avidin-Biotin Complex (ABC) and Labeled Streptavidin Biotin (LSAB) methods. In the ABC method free avidin (or streptavidin) is used as a bridge/link between the biotinylated antibody and а biotinylated reporter molecule, resulting in three reporter molecules coupled to the biotinylated antibody. The LSAB method employs a reporter-labeled streptavidin (avidin or neutravidin can alternatively be used) to detect the bound biotinylated-secondary antibody on the tissue section, blotting membrane or ELISA plate, improving the sensitivity of detection by 8-fold. The LSAB method is used when the avidin-biotin-enzyme complex in the ABC method becomes too large to penetrate the tissue.\r\n</p>'},
#  {'Price': '$50.00',
#   'Product Title': '\nRabbit Anti-Human IgG (H+L) Secondary Antibody, Unconjugated ',
#   'Product URL': 'https://www.bosterbio.com/unconjugated-rabbit-anti-human-igg-secondary-antibody-ba1041-boster.html',
#   'SKU:': 'BA1041',
#   'Pack Size:': '1mg',
#   'Validated Species:': 'Human',
#   'Host:': 'Rabbit',
#   'Clonality:': 'Polyclonal',
#   'Application:': 'ELISA, IF, IHC, ICC, WB',
#   ' Datasheet ': '/media/pdf/BA1041_DS.pdf',
#   ' Protocols ': 'https://www.bosterbio.com/protocol-and-troubleshooting/'},
#  {'Price': '$80.00',
#   'Product Title': '\nGoat Anti-Human IgA Secondary Antibody, HRP Conjugate ',
#   'Product URL': 'https://www.bosterbio.com/hrp-conjugated-goat-anti-human-iga-alpha-chain-specific-secondary-antibody-ba1066-boster.html',
#   'SKU': 'BA1066',
#   'Pack size ': '0.25 ml',
#   'Applications': 'Western blot',
#   'Product Name': 'Goat Anti-Human IgA Secondary Antibody, HRP Conjugate',
#   'Synonyms': 'HRP-conjugated goat anti-human IgA',
#   'Description': 'Goat Anti-Human IgA Secondary Antibody, HRP Conjugate, for the indirect sensitive immunodetection and/or quantification of target proteins through Dotblot, WB, or ELISA by assaying an HRP-catalyzed reaction product in the vicinity of the antigen-primary antibody-secondary antibody-HRP complex.',
#   'Reagent Type': 'Secondary antibody, reporter enzyme labeled',
#   'Label': 'HRP (Horseradish Peroxidase)',
#   'Host': 'Goat',
#   'Target Species': 'Human',
#   'Antibody Class': 'IgG',
#   'Clonality': 'Polyclonal',
#   'Immunogen': 'Whole molecule human IgA',
#   'Purification': 'Immunoaffinity Chromatography',
#   'Specificyity': 'Human IgA specific; No cross-reactivity with human IgG/IgM',
#   'Form Supplied': 'Liquid: concentrated buffered stock solution',
#   'Formulation': '0.5 mg HRP-conjugated secondary antibody\r\n\t\t\t0.01 M PBS (PH 7.4)\r\n\t\t\t50% glycerol',
#   'Pack Size': '0.25 ml',
#   'Concentration': '1 mg/ml',
#   'Application': 'ELISA*, WB*, Dot blot  *Our Boster Guarantee covers the use of this product in the above marked tested applications.',
#   'Storage': '4C for 1 year',
#   'Precautions': 'FOR RESEARCH USE ONLY. NOT FOR DIAGNOSTIC OR CLINICAL USE',
#   'Sample Type': 'SDS-PAGE separated-, membrane-immobilized-, mouse primary-antibody-probed proteins from cell/tissue lysates',
#   'Assay Type': 'Immunoassay',
#   'Assay Purpose': 'Protein detection/quantification',
#   'Technique': 'Immunodetection of target antibody with HRP reporter enzyme',
#   'Equipment Needed': 'WB/Dot blot/ELISA instrumentation; X-ray film cassette or a charge-coupled device (CCD) imager; Spectrophotometer',
#   'Compatibility with Reagents': 'Incompatible with sodium azide and metals  incompatible with high phosphate concentrations',
#   'Specific': 'High signal-to-noise ratio',
#   'Sensitive': 'Detects low-abundant targets due to an optimal number of HRP molecules per antibody',
#   'High Signal Amplification': 'Multiple secondary antibodies can bind to a single primary antibody;Secondary antibodies Fc regions provide further binding locations for biotin, or enable the use of ABC and SABC',
#   'Fast': 'Generates strong signals in a relatively short time span',
#   'Quantifieable': 'Allows quantification of detected signal',
#   'Easy to Use': 'Supplied in a workable liquid format ',
#   'Flexible': 'HRP: compatible with chromogenic, fluorogenic and chemiluminescent substrates;',
#   'Convenient': 'HRP’s small size: no interference with the primary/secondary antibody interaction; no steric hindrance to antibody/antigen complexes',
#   ' Datasheet ': '/media/pdf/BA1066_DS.pdf',
#   ' Protocols ': 'https://www.bosterbio.com/protocol-and-troubleshooting/',
#   'Background': 'Most commonly, secondary antibodies are generated by immunizing the host animal with a pooled population of immunoglobulins from the target species. The host antiserum is then purified through immunoaffinity chromatography to remove all host serum proteins, except the specific antibody of interest, and are then modified with antibody fragmentation, label conjugation, etc., to generate highly specific reagents. Secondary antibodies can be conjugated to a large number of labels, including enzymes, biotin, and fluorescent dyes/proteins. Here, the antibody provides the specificity to locate the protein of interest, and the label generates a detectable signal. The label of choice depends upon the experimental application. | <p>Horseradish peroxidase (HRP) is extensively used for labeling secondary antibodies in ELISA, western blot, dot blot and immunohistochemistry. The HRP enzyme is made visible using a substrate that, when oxidized by HRP in the presence of hydrogen peroxide as an oxidizing agent, yields a characteristic change that is detectable by specific detection methods. The substrates commonly used with HRP fall into different categories including chromogenic, fluorogenic, and chemiluminescent substrates depending on whether they produce a colored, fluorimetric or luminescent derivative respectively. The intensity of the signal is proportional to peroxidase activity and is a measure of the number of enzyme molecules reacting, hence of the amount of recognized primary antibodies, and thus of the amount of target antigen.</p>'},
#  {'Price': '$80.00',
#   'Product Title': '\nRabbit Anti-Human IgG (H+L) Secondary Antibody, FITC Conjugate ',
#   'Product URL': 'https://www.bosterbio.com/fitc-conjugated-rabbit-anti-human-igg-h-l-secondary-antibody-ba1114-boster.html',
#   'SKU': 'BA1114',
#   'Pack size ': '0.5 ml',
#   'Applications': 'Flow Cytometry, IHC, ICC',
#   'Product Name': 'Rabbit Anti-Human IgG (H+L) Secondary Antibody, FITC Conjugate',
#   'Synonyms': 'FITC-conjugated Rabbit Anti-Human IgG; Rabbit Anti-Human IgG-FITC Secondary Antibody; Fluorescein-labeled Rabbit Anti-Human IgG Secondary Antibody',
#   'Description': 'Rabbit Anti-Human IgG (H+L) Secondary Antibody, FITC Conjugate, for detection, localization and quantification of target proteins in a sample via indirect immunofluorescence in IHC-P, IHC-F, ICC, or FCM.',
#   'Reagent Type': 'Fluorophore-conjugated secondary antibody',
#   'Label': 'FITC',
#   'Host': 'Rabbit',
#   'Target Species': 'Human',
#   'Antibody Class': 'IgG',
#   'Clonality': 'Polyclonal',
#   'Immunogen': 'Whole molecule human IgG',
#   'Purification': 'Immunoaffinity chromatography',
#   'Specificity': 'Human IgG specific',
#   'Form Supplied': 'Liquid, concentrated buffered stock solution',
#   'Formulation': '0.5 mg FITC-conjugated secondary antibody\r\n\t\t\t0.01 M PBS (PH 7.4)\r\n\t\t\t0.01% Thimerosal\r\n\t\t\t50% glycerol',
#   'Pack Size': '0.5 ml',
#   'Concentration': '1 mg/ml',
#   'Application': 'Flow Cytometry (FCM), Immunohistochemistry (paraffin-embedded (IHC-P) and frozen(IHC-F) sections), Immunocytochemistry (ICC)  *Our Boster Guarantee covers the use of this product in the above marked tested applications.',
#   'Storage': '4C for 1 year',
#   'Precautions': 'FOR RESEARCH USE ONLY. NOT FOR DIAGNOSTIC OR CLINICAL USE',
#   'Sample Type': 'Human primary-antibody-probed Single cell suspension, Formalin-fixed paraffin-embedded (FFPE) tissue sections, Thawed frozen samples (IHC-F)',
#   'Assay Type': 'Immunoanalytical',
#   'Assay Purpose': 'Protein detection/quantification',
#   'Technique': 'Immunofluorescence',
#   'Equipment Needed': 'Excitation light source; Filter set and detector: fluorescence microscope (can be combined with confocal microscope), fluorescence plate-reader, flow cytometer, or cell sorter',
#   'Additional Materials Required': 'Primary antibody against target antigen raised in human; Diluent Buffer (PBS or TBS); Application-specific reagents and appliances;',
#   'Specific': 'High signal-to-noise ratio',
#   'High Signal Amplification': 'Multiple secondary antibodies can bind to a single primary antibody; Multiple FITC molecules bind to a single secondary antibody',
#   'Fast': 'Fewer processing steps - no need to add a substrate; Less optimization required compared to enzymatic detection; Generates strong signals in a relatively short time span; Fluorescence can be observed directly',
#   'Quantifieable': 'Allows quantification of detected signal',
#   'Easy to Use': 'Supplied in a workable liquid format ',
#   'Multiplex Compatibility': 'Colocalization studies possible, even in close proximity: use primary antibodies from different host species for simultaneous detection by fluorophore-conjugated secondary antibodies; use multiple differently colored fluorophores in the same experiment for target differentiation',
#   'Dynamic range': 'Good linearity within detection limits',
#   ' Datasheet ': '/media/pdf/BA1114_DS.pdf',
#   ' Protocols ': 'https://www.bosterbio.com/protocol-and-troubleshooting/',
# ...
#   'Target Info': '*if product is indicated to react with multiple species, protein info is based on the human gene.'},
#  {'Price': '$510.00',
#   'Product Title': '\nGoat Anti-Rabbit IgG Beads (1-1.5mg/ml) ',
#   'Product URL': 'https://www.bosterbio.com/goat-anti-rabbit-igg-beads-1-1-5mg-ml-b0003-10-boster.html',
#   'SKU': 'B0003-10',
#   'Size': '10ml',
#   'Product Name': 'Goat Anti-Rabbit IgG Beads (1-1.5mg/ml)                                            ',
#   'SKU/Catalog Number': 'B0003-10',
#   'Storage & Handling': 'Storage: Store at 4°C for frequent use, at -20°C for at least one year.',
#   'Description': 'Goat Anti-Rabbit IgG Beads (1-1.5mg/ml), For purification of rabbit IgG class of antibodies or proteins with affinity to goat',
#   'Cite This Product': 'Goat Anti-Rabbit IgG Beads (1-1.5mg/ml) (Boster Biological Technology, Pleasanton CA, USA, Catalog # B0003-10)',
#   'Specificity': 'Goat Anti-Rabbit IgG Beads (1-1.5mg/ml) (B0003-10) reacts with  , in native form and recombinant. Superfamily members of  are not reactive to B0003-10.',
#   ' Datasheet ': '/media/pdf/B0003-10_DS.pdf',
#   ' Protocols ': 'https://www.bosterbio.com/protocol-and-troubleshooting/',
#   ' COA ': 'https://www.bosterbio.com/antibody-coa?sku=B0003-10',
#   ' MSDS ': 'https://www.bosterbio.com/antibody-msds?sku=B0003-10',
#   'Assay Details': 'Our Boster Quality Guarantee for Goat Anti-Rabbit IgG Beads (1-1.5mg/ml) covers its use in the following applications. | *The recommended dilution ratios/concentrations are for reference only and optimal dilutions/concentrations should be determined by the end user. | Boster Kit Box',
#   'Target Info': '*if product is indicated to react with multiple species, protein info is based on the human gene.'},
#  {'Price': '$960.00',
#   'Product Title': '\nGoat Anti-Rabbit IgG Beads (1-1.5mg/ml) ',
#   'Product URL': 'https://www.bosterbio.com/goat-anti-rabbit-igg-beads-1-1-5mg-ml-b0003-25-boster.html',
#   'SKU': 'B0003-25',
#   'Size': '25ml',
#   'Product Name': 'Goat Anti-Rabbit IgG Beads (1-1.5mg/ml)                                            ',
#   'SKU/Catalog Number': 'B0003-25',
#   'Storage & Handling': 'Storage: Store at 4°C for frequent use, at -20°C for at least one year.',
#   'Description': 'Goat Anti-Rabbit IgG Beads (1-1.5mg/ml), For purification of rabbit IgG class of antibodies or proteins with affinity to goat',
#   'Cite This Product': 'Goat Anti-Rabbit IgG Beads (1-1.5mg/ml) (Boster Biological Technology, Pleasanton CA, USA, Catalog # B0003-25)',
#   'Specificity': 'Goat Anti-Rabbit IgG Beads (1-1.5mg/ml) (B0003-25) reacts with  , in native form and recombinant. Superfamily members of  are not reactive to B0003-25.',
#   ' Datasheet ': '/media/pdf/B0003-25_DS.pdf',
#   ' Protocols ': 'https://www.bosterbio.com/protocol-and-troubleshooting/',
#   ' COA ': 'https://www.bosterbio.com/antibody-coa?sku=B0003-25',
#   ' MSDS ': 'https://www.bosterbio.com/antibody-msds?sku=B0003-25',
#   'Assay Details': 'Our Boster Quality Guarantee for Goat Anti-Rabbit IgG Beads (1-1.5mg/ml) covers its use in the following applications. | *The recommended dilution ratios/concentrations are for reference only and optimal dilutions/concentrations should be determined by the end user. | Boster Kit Box',
#   'Target Info': '*if product is indicated to react with multiple species, protein info is based on the human gene.'},
#  {'Price': '$1,000.00',
#   'Product Title': '\nHRP Conjugated anti-Goat IgG Super Vision Assay Kit ',
#   'Product URL': 'https://www.bosterbio.com/hrp-conjugated-anti-goat-igg-super-vision-assay-kit-sv0003-2-boster.html',
#   'SKU': 'SV0003-2',
#   'Size': '100ml/kit',
#   'Clonality': 'Polyclonal',
#   'Host': 'Rabbit',
#   'Applications': 'IHC',
#   'Product Name': 'HRP Conjugated anti-Goat IgG Super Vision Assay Kit                                            ',
#   'SKU/Catalog Number': 'SV0003-2',
#   'Storage & Handling': '4°C for one year. Avoid freezing.',
#   'Components': '1. 5% BSA Blocking Reagent: 100ml, for blocking tissue sections.  \n2. Secondary Antibody (polymerization HRP conjugated anti-goat IgG): 100ml  \n3. 3%H2O2: 100ml.\n',
#   'Description': 'HRP Conjugated anti-Goat IgG Super Vision Assay Kit, with the specific secondary antibody and all the reagents needed for performing IHC-P;IHC-F;ICC',
#   'Cite This Product': 'HRP Conjugated anti-Goat IgG Super Vision Assay Kit (Boster Biological Technology, Pleasanton CA, USA, Catalog # SV0003-2)',
#   'Specificity': 'HRP Conjugated anti-Goat IgG Super Vision Assay Kit (SV0003-2) reacts with  , in native form and recombinant. Superfamily members of  are not reactive to SV0003-2.',
#   ' Datasheet ': '/media/pdf/SV0003-2_DS.pdf',
#   ' Protocols ': 'https://www.bosterbio.com/protocol-and-troubleshooting/',
#   'Assay Details': 'Our Boster Quality Guarantee for HRP Conjugated anti-Goat IgG Super Vision Assay Kit covers its use in the following applications. | *The recommended dilution ratios/concentrations are for reference only and optimal dilutions/concentrations should be determined by the end user. | Boster Kit Box',
#   'Target Info': '*if product is indicated to react with multiple species, protein info is based on the human gene.'},
#  {'Price': '$1,000.00',
#   'Product Title': '\nHRP Conjugated anti-Rabbit IgG Super Vision Assay Kit ',
#   'Product URL': 'https://www.bosterbio.com/hrp-conjugated-anti-rabbit-igg-super-vision-assay-kit-sv0002-2-boster.html',
#   'SKU': 'SV0002-2',
#   'Size': '100ml/kit',
#   'Clonality': 'Polyclonal',
#   'Host': 'Goat',
#   'Applications': 'IHC',
#   'Product Name': 'HRP Conjugated anti-Rabbit IgG Super Vision Assay Kit                                            ',
#   'SKU/Catalog Number': 'SV0002-2',
#   'Storage & Handling': '4°C for one year. Avoid freezing.',
#   'Components': '1. 5% BSA Blocking Reagent: 100ml, for blocking tissue sections.  \r\n2. Secondary Antibody (polymerization HRP conjugated anti-rabbit IgG): 100ml.  \r\n3. 3%H2O2: 100ml.\r\n',
#   'Description': 'HRP Conjugated anti-Rabbit IgG Super Vision Assay Kit, with the specific secondary antibody and all the reagents needed for performing IHC-P;IHC-F;ICC',
#   'Cite This Product': 'HRP Conjugated anti-Rabbit IgG Super Vision Assay Kit (Boster Biological Technology, Pleasanton CA, USA, Catalog # SV0002-2)',
#   'Specificity': 'HRP Conjugated anti-Rabbit IgG Super Vision Assay Kit (SV0002-2) reacts with  , in native form and recombinant. Superfamily members of  are not reactive to SV0002-2.',
#   ' Datasheet ': '/media/pdf/SV0002-2_DS.pdf',
#   ' Protocols ': 'https://www.bosterbio.com/protocol-and-troubleshooting/',
#   'Assay Details': 'Our Boster Quality Guarantee for HRP Conjugated anti-Rabbit IgG Super Vision Assay Kit covers its use in the following applications. | *The recommended dilution ratios/concentrations are for reference only and optimal dilutions/concentrations should be determined by the end user. | Collagen IV was detected in paraffin-embedded sections of rat liver tissues using rabbit anti- Collagen IV Antigen Affinity purified polyconal antibody (Catalog # PA1521) at 1 ??g/mL. The immunohistochemical section was developed using Super Vision Assay method (Catalog # SV0002). | GST3/GST Pi was detected in paraffin-embedded sections of human intestinal cancer tissues using rabbit anti- GST3/GST Pi Antigen Affinity purified polyconal antibody (Catalog # PB 9184) at 1 Î¼g/mL. The immunohistochemical section was developed using Super Vision Assay method (Catalog # SV0002).  | DDB1 was detected in paraffin-embedded sections of human intestinal cancer tissues using rabbit anti- DDB1 Antigen Affinity purified polyconal antibody (Catalog # PB9578) at 1 Î¼g/mL. The immunohistochemical section was developed using Super Vision Assay method (Catalog # SV0002).  | ABCB11 was detected in paraffin-embedded sections of rat liver tissues using rabbit anti- ABCB11 Antigen Affinity purified polyconal antibody (Catalog # PB9414) at 1 Î¼g/mL. The immunohistochemical section was developed using Super Vision Assay method (Catalog # SV0002). ',
#   'Target Info': '*if product is indicated to react with multiple species, protein info is based on the human gene.'},
#  {'Price': '$0.00',
#   'Product Title': '\nzero dollar test product ',
#   'Product URL': 'https://www.bosterbio.com/zero-dollar-test-product-zerotest-boster.html',
#   'Available Sizes:': '5ug, 25ug, 1mg',
#   'Applications:': 'ex vivo Cell Culture',
#   'Source:': 'E. Coli',
#   'Purity:': 'Greater than 95.0% as determined by SDS-PAGE.',
#   ' Datasheet ': 'https://www.bosterbio.com/datasheet?sku=zerotest',
#   ' Protocols ': 'https://www.bosterbio.com/protocol-and-troubleshooting/'},
#  {'Price': '$230.00',
#   'Product Title': '\nRecombinant Human Exodus-2 (CCL21) Protein ',
#   'Product URL': 'https://www.bosterbio.com/recombinant-human-exodus-2-ccl21-proto00585-1.html',
#   'SKU': 'PROTO00585-1',
#   'Size': 'Various Sizes',
#   'Applications': 'Cell Culture',
#   'Product Name': 'Recombinant Human Exodus-2 (CCL21) Protein',
#   'SKU/Catalog Number': 'PROTO00585-1',
#   'Storage & Handling': 'Store in -20°C for long term storage. After reconstitution, store in 4°C for short term usage within a few days. Avoid freeze-thaw cycles. ',
#   'Description': 'Exodus-2 is a CC chemokine that signals through the CCR7 receptor.  It is expressed in lymph nodes of certain endothelial cells, and in the spleen and appendix.  Exodus-2 chemoattracts T and B lymphocytes and inhibits hematopoiesis.  Exodus-2 contains six cysteine residues, including the four conserved cysteines present in CC chemokines.  Recombinant human Exodus-2 is a 12.2 kDa protein containing 111 amino acid residues.',
#   'Cite This Product': 'Recombinant Human Exodus-2 (CCL21) Protein (Boster Biological Technology, Pleasanton CA, USA, Catalog # PROTO00585-1)',
#   'Immunogen': 'Expression system for standard: E.coli; Immunogen sequence: S24-P134',
#   'Uniprot Id': 'O00585',
#   'Gene Name': 'CCL21',
#   'Protein Name': 'C-C motif chemokine 21',
#   'Tissue Specificity': ' Highly expressed in high endothelial venules of lymph nodes, spleen and appendix. Intermediate levels found in small intestine, thyroid gland and trachea. Low level expression in thymus, bone marrow, liver, and pancreas. Also found in tonsil, fetal heart and fetal spleen.',
#   'Alternative Names': 'C-C motif chemokine 21;6Ckine;Beta-chemokine exodus-2;Secondary lymphoid-tissue chemokine;SLC;Small-inducible cytokine A21;CCL21;SCYA21;UNQ784/PRO1600; CCL21, 6Ckine, SLC',
#   'Subcellular Localization': ' Secreted.',
#   'Protein Function': ' Inhibits hemopoiesis and stimulates chemotaxis. Chemotactic in vitro for thymocytes and activated T-cells, but not for B-cells, macrophages, or neutrophils. Shows preferential activity towards naive T-cells. May play a role in mediating homing of lymphocytes to secondary lymphoid organs. Binds to atypical chemokine receptor ACKR4 and mediates the recruitment of beta-arrestin (ARRB1/2) to ACKR4.',
#   ' Datasheet ': 'https://www.bosterbio.com/datasheet?sku=PROTO00585-1',
#   ' Protocols ': 'https://www.bosterbio.com/protocol-and-troubleshooting/',
#   'Target Info': 'Here are featured tools and databases that you might find useful.'},
#  {'Price': '$250.00',
#   'Product Title': '\nExodus-2 Human Recombinant Protein (CCL21) ',
#   'Product URL': 'https://www.bosterbio.com/exodus-2-human-recombinant-protein-ccl21-proto00585-boster.html',
#   'SKU': 'PROTO00585',
#   'Size': '5ug, 20ug, 1mg',
#   'Applications': 'Cell Culture',
#   'Product Name': 'Exodus-2 Human Recombinant Protein (CCL21)',
#   'SKU/Catalog Number': 'PROTO00585',
#   'Storage & Handling': 'Store in -20°C for long term storage. After reconstitution, store in 4°C for short term usage within a few days. Avoid freeze-thaw cycles. ',
#   'Description': 'Exodus-2 Human Recombinant produced in E.Coli as a single, non-glycosylated, polypeptide chain containing 1112219 Dalton. The CCL21 is purified by proprietary chromatographic techniques.',
#   'Cite This Product': 'Exodus-2 Human Recombinant Protein (CCL21) (Boster Biological Technology, Pleasanton CA, USA, Catalog # PROTO00585)',
#   'Immunogen': 'Expression system for standard: E.coli; Immunogen sequence: S24-P134',
#   'Uniprot Id': 'O00585',
#   'Gene Name': 'CCL21',
#   'Protein Name': 'C-C motif chemokine 21',
#   'Tissue Specificity': ' Highly expressed in high endothelial venules of lymph nodes, spleen and appendix. Intermediate levels found in small intestine, thyroid gland and trachea. Low level expression in thymus, bone marrow, liver, and pancreas. Also found in tonsil, fetal heart and fetal spleen.',
#   'Alternative Names': 'C-C motif chemokine 21;6Ckine;Beta-chemokine exodus-2;Secondary lymphoid-tissue chemokine;SLC;Small-inducible cytokine A21;CCL21;SCYA21;UNQ784/PRO1600;',
#   'Subcellular Localization': ' Secreted.',
#   'Protein Function': ' Inhibits hemopoiesis and stimulates chemotaxis. Chemotactic in vitro for thymocytes and activated T-cells, but not for B-cells, macrophages, or neutrophils. Shows preferential activity towards naive T-cells. May play a role in mediating homing of lymphocytes to secondary lymphoid organs. Binds to atypical chemokine receptor ACKR4 and mediates the recruitment of beta-arrestin (ARRB1/2) to ACKR4.',
#   ' Datasheet ': 'https://www.bosterbio.com/datasheet?sku=PROTO00585',
#   ' Protocols ': 'https://www.bosterbio.com/protocol-and-troubleshooting/',
#   'Target Info': 'Here are featured tools and databases that you might find useful.'},
#  {'Price': '$250.00',
#   'Product Title': '\nCHIKV Chikungunya Mutant (A226V) E1 Recombinant Protein ',
#   'Product URL': 'https://www.bosterbio.com/chikv-chikungunya-mutant-a226v-e1-recombinant-protein-protg0lwx6-boster.html',
#   'SKU': 'PROTG0LWX6',
#   'Size': '2ug, 10ug, 1mg',
#   'Applications': 'Cell Culture',
#   'Source': 'Rabbit',
#   'Product Name': 'CHIKV Chikungunya Mutant (A226V) E1 Recombinant Protein',
#   'SKU/Catalog Number': 'PROTG0LWX6',
#   'Storage & Handling': 'Store in -20°C for long term storage. After reconstitution, store in 4°C for short term usage within a few days. Avoid freeze-thaw cycles. ',
#   'Description': 'Recombinant Chikungunya Mutant (A226V) Ethe wild-type CHIKV Ethe CHIKV Mutant is approximately 50kDa. The EE2-6K-E1 protein region. CHIKV Mutant is purified by proprietary chromatographic technique.',
#   'Cite This Product': 'CHIKV Chikungunya Mutant (A226V) E1 Recombinant Protein (Boster Biological Technology, Pleasanton CA, USA, Catalog # PROTG0LWX6)',
#   'Expression Source': 'Rabbit',
#   'Uniprot Id': 'G0LWX6',
#   'Gene Name': 'E2-6K-E1',
#   'Protein Name': 'Dual specificity protein phosphatase 1 ',
#   'Tissue Specificity': ' Expressed at high levels in the lung, liver placenta and pancreas. Moderate levels seen in the heart and skeletal muscle. Lower levels found in the brain and kidney. .',
#   'Alternative Names': 'Structural polyprotein, E2-6K-E1 region ',
#   'Subcellular Localization': ' Nucleus .',
#   'Protein Function': " Dual specificity phosphatase that dephosphorylates MAP kinase MAPK1/ERK2 on both 'Thr-183' and 'Tyr-185', regulating its activity during the meiotic cell cycle. .",
#   ' Datasheet ': 'https://www.bosterbio.com/datasheet?sku=PROTG0LWX6',
#   ' Protocols ': 'https://www.bosterbio.com/protocol-and-troubleshooting/',
#   'Target Info': 'Here are featured tools and databases that you might find useful.'}]

# %%
#for i in empty:
 #   new.append(i)
#len(new)
# Out:
# 174

# %%
df=pd.DataFrame(empty)
df.to_excel("sample_10nm_Colloidal_secondary.xlsx",header=True,index=False)

# %%
source=requests.get("https://www.bosterbio.com/nuclear-fast-red-ar0008-boster.html").text
soup=BeautifulSoup(source,'lxml')

# %%
sizes=[]
alter={}
alternate_price=soup.find("span",{"class":"price"}).text
alter.update({"Price":alternate_price})
sizes.append(alter)
sizes
# Out:
# [{'Price': '$15.00'}]

# %%
def para_data(soup):
    dictt={}
    try:
        deal=[]
        details=soup.find('div',{"class":"product_main_column"})
        details=details.findAll(['h2','p'])
        details
        for n,det in enumerate(details):
            deal.append(str(det))


        deal=' '.join(deal) 
        deal=deal.split("<h2>")
        for d in deal:
            d=d.split("</h2>")
            if len(d)>1:
                dictt.update({d[0]:d[1]})
    except:
        pass

    return dictt

# %%
publications(soup)
# Out:
# {'Publication_1': 'Li D, He W, Liu X, Zheng S, Qi Y, Li H, Mao F, Liu J, Sun Y, Pan L, Du K, Ye K, Li W, Sui J. Elife. 2017 Sep 26;6. pii: e26738. doi: 10.7554/eLife.26738. A potent human neutralizing antibody Fc-dependently reduces established HBV infections PubMed ID 28949917 Zhao JR, Cheng WW, Wang YX, Cai M, Wu WB, Zhang HJ. Cell Death Dis. 2018 Jan 24;9(2):94. doi: 10.1038/s41419-017-0108-2. Identification of microRNA signature in the progression of gestational trophoblastic disease. PubMed ID 29367697 Ni W, Zhang Y, Zhan Z, Ye F, Liang Y, Huang J, Chen K, Chen L, Ding Y. J Hematol Oncol. 2017 Apr 19;10(1):91. doi: 10.1186/s13045-017-0449-4. A novel lncRNA uc.134 represses hepatocellular carcinoma progression by inhibiting CUL4A-mediated ubiquit... PubMed ID 28420424',
#  'Publication_link_1': 'https://www.ncbi.nlm.nih.gov/pubmed/28949917'}

# %%
publicat={}
pubtext_list=[]
pubalpha_list=[]
pub=soup.find('div',{"class":"publications product_publications"})
pub_text=pub.findAll("div",{"class":"col-md-9"})
pub_alpha=pub.findAll("div",{"class":"col-md-3"})
for pt in pub_text:
    pubtext_list.append(pt.text)
pub_alpha    
for pa in pub_alpha:
    pubalpha_list.append(pa.a["href"])    
for i in range(len(pub_alpha)):
    publicat.update({"Publication_"+str(i+1):pubtext_list[i],"Publication_link_"+str(i+1):pubalpha_list[i]})
publicat
# Out:
# {'Publication_1': '\n                        Li D, He W, Liu X, Zheng S, Qi Y, Li H, Mao F, Liu J, Sun Y, Pan L, Du K, Ye K, Li W, Sui J. Elife. 2017 Sep 26;6. pii: e26738. doi: 10.7554/eLife.26738. A potent human neutralizing antibody Fc-dependently reduces established HBV infections                    ',
#  'Publication_link_1': 'https://www.ncbi.nlm.nih.gov/pubmed/28949917',
#  'Publication_2': '\n                        Zhao JR, Cheng WW, Wang YX, Cai M, Wu WB, Zhang HJ. Cell Death Dis. 2018 Jan 24;9(2):94. doi: 10.1038/s41419-017-0108-2. Identification of microRNA signature in the progression of gestational trophoblastic disease.                    ',
#  'Publication_link_2': 'https://www.ncbi.nlm.nih.gov/pubmed/29367697',
#  'Publication_3': '\n                        Ni W, Zhang Y, Zhan Z, Ye F, Liang Y, Huang J, Chen K, Chen L, Ding Y. J Hematol Oncol. 2017 Apr 19;10(1):91. doi: 10.1186/s13045-017-0449-4. A novel lncRNA uc.134 represses hepatocellular carcinoma progression by inhibiting CUL4A-mediated ubiquit...                    ',
#  'Publication_link_3': 'https://www.ncbi.nlm.nih.gov/pubmed/28420424'}

# %%
# Out:
# ['L125A',
#  'L125B',
#  'L126A',
#  'L126B',
#  'L159B',
#  'L159A',
#  'L128A',
#  'L128B',
#  'L129B',
#  'L129A',
#  'L131B',
#  'L131A',
#  'L132B',
#  'L132A',
#  '612-101-033',
#  '201-4633S',
#  '23865-5',
#  '23867-5',
#  '600-142-098',
#  '800-102-098',
#  '800-103-098',
#  '701-401-002',
#  '701-405-002',
#  '701-406-002',
#  '701-402-002',
#  '701-408-002',
#  '701-403-002',
#  '701-409-002',
#  '701-400-002',
#  '702-403-002',
#  '603-705-C37',
#  '603-706-C37',
#  '603-446-002-0.5',
#  '603-441-002-0.5',
#  '603-442-002-0.5',
#  '603-443-002-0.5',
#  '603-444-002-0.5',
#  '603-445-002-0.5',
#  '603-702-C37',
#  '603-4302-0500',
#  '603-703-C37',
#  '603-4202-0500',
#  '603-709-C37',
#  '603-700-C37',
#  '346022-1ML',
#  'CLAS99-003',
#  '603-701-C37',
#  'PAB29157',
#  'PAB29158',
#  'PAB29159',
#  '610-455-C46',
#  '610-456-C46S',
#  '610-456-C46',
#  '610-457-C46S',
#  '610-457-C46',
#  '609-1112',
#  '609-4112',
#  '609-1612',
#  '609-4612',
#  '609-4212',
#  '609-4312',
#  '609-4912',
#  '609-1912',
#  '610-146-121',
#  '610-746-124',
#  '610-446-020',
#  '610-646-002',
#  '611-146-122',
#  '611-746-127',
#  '611-646-122',
#  '603-446-002',
#  '603-441-002',
#  '603-442-002',
#  '603-443-002',
#  '603-444-002',
#  '603-445-002',
#  '605-446-002',
#  '605-441-002',
#  '605-442-002',
#  '605-443-002',
#  '605-444-002',
#  '605-445-002',
#  '610-746-002',
#  '610-446-002',
#  '610-641-002',
#  '610-441-002',
#  '610-741-002',
#  '610-742-002',
#  '610-442-002',
#  '610-743-002',
#  '610-443-002',
#  '610-444-002',
#  '610-744-002',
#  '610-445-002',
#  '610-745-002',
#  '611-146-002',
#  '611-141-002',
#  '611-142-002',
#  '611-143-002',
#  '611-144-002',
#  '23760-2',
#  '605-746-002-0.5',
#  '605-741-002',
#  '605-741-125',
#  '605-742-125',
#  '605-742-002',
#  '605-743-002',
#  '605-743-125',
#  '605-443-013',
#  '605-743-002-0.5',
#  '605-744-002-0.5',
#  '605-744-002',
#  '605-744-125',
#  '605-444-013',
#  '605-745-125',
#  '605-745-002',
#  '605-445-013',
#  'PAB10569',
#  'PAB10575',
#  '23757-2',
#  'PAB10563',
#  'PAB10576',
#  'PAB10570',
#  '23766-1',
#  '23759-2',
#  'PAB10567',
#  'PAB10573',
#  'PAB10579',
#  'PAB10568',
#  'PAB10574',
#  '23758-2',
#  '23765-1',
#  'PAB10562',
#  '620-146-440',
#  'PAB10601',
#  'PAB10595',
#  'PAB10596',
#  'PAB10602',
#  'PAB10593',
#  'PAB10599',
#  'PAB10600',
#  'PAB10594',
#  'PAB10597',
#  'PAB10603',
#  'PAB10592',
#  'PAB10598',
#  'PAB10628',
#  'PAB10612',
#  'PAB10613',
#  'PAB10629',
#  '611-145-002',
#  '612-446-002',
#  '612-441-002',
#  '612-442-002',
#  '612-443-002',
#  '612-444-002',
#  '612-445-002',
#  '613-446-002',
#  '613-441-002',
#  '613-442-002',
#  '613-443-002',
#  '613-444-002',
#  '613-445-002',
#  'PAB10427',
#  'PAB10428',
#  'PAB10425',
#  'PAB10426',
#  'PAB10429',
#  'PAB10424',
#  'PAB10449',
#  'PAB10434',
#  'PAB10450',
#  'PAB10447',
#  'PAB10448',
#  'PAB10432',
#  'PAB10435',
#  'PAB10451',
#  'PAB10446',
#  'PAB10467',
#  'PAB10484',
#  'PAB10485',
#  'PAB10465',
#  'PAB10482',
#  'PAB10466',
#  'PAB10483',
#  'PAB10468',
#  'PAB10464',
#  'PAB10481',
#  '603-146-002',
#  '603-141-002',
#  '603-142-002',
#  '603-143-002',
#  '603-145-002',
#  'PAB10501',
#  'PAB10507',
#  'PAB10508',
#  'PAB10502',
#  '603-146-126',
#  '603-146-002-0.5',
#  '603-141-002-0.5',
#  '609-145-002-0.5',
#  '609-145-002',
#  '609-445-002-0.5',
#  '609-1316-0100',
#  '209-301-003',
#  'CL6002',
#  'CL6002F',
#  'CL6100',
#  'CL6200',
#  'CL6200F',
#  'CL6100F',
#  'CLF001AP',
#  'CLF001F',
#  'CLF004',
#  'CLF003AP',
#  '11-322-C100',
#  '11-322-C025',
#  '618-106-006',
#  '618-101-006',
#  '618-105-006',
#  '618-102-006',
#  '618-103-006',
#  '618-109-006',
#  '618-100-006',
#  '709-1106',
#  '609-1106',
#  '609-4106',
#  '609-4506',
#  '609-1506',
#  '709-1506',
#  '609-1606',
#  '709-1606',
#  '609-4606',
#  '609-1206',
#  '609-4206',
#  '709-1206',
#  '609-4306',
#  '709-1306',
#  '609-1306',
#  '609-1906',
#  '609-4906',
#  '709-1006',
#  '609-4006',
#  '609-1006',
#  '617-101-006',
#  '617-105-006',
#  '617-106-006',
#  '617-102-006',
#  '617-103-006',
#  '617-109-006',
#  '610-743-124',
#  '610-643-002',
#  '610-443-020',
#  '610-744-124',
#  '610-644-002',
#  '610-444-020',
#  '610-645-002',
#  '610-445-020',
#  '610-745-124',
#  '610-145-002',
#  '23806-2',
#  'PAB10745',
#  'PAB10739',
#  'PAB10781',
#  'PAB10733',
#  'PAB10763',
#  'PAB10782',
#  'PAB10764',
#  'PAB10746',
#  '23810-2',
#  '23817-2',
#  'PAB10734',
#  '23796-2',
#  '23803-1',
#  'PAB10740',
#  '23815-2',
#  'PAB10749',
#  'PAB10737',
#  'PAB10785',
#  'PAB10767',
#  'PAB10743',
#  'PAB10744',
#  'PAB10780',
#  'PAB10732',
#  'PAB10762',
#  'PAB10738',
#  'PAB10795',
#  'PAB10789',
#  'PAB10796',
#  'PAB10790',
#  'PAB10787',
#  'PAB10793',
#  'PAB10788',
#  'PAB10794',
#  'PAB10791',
#  'PAB10792',
#  'PAB10786',
#  'PAB10841',
#  'PAB10817',
#  'PAB10823',
#  '612-445-026',
#  '612-145-120',
#  'PAB10887',
#  'PAB10845',
#  'PAB10851',
#  'PAB10869',
#  'PAB10857',
#  'PAB10852',
#  'PAB10870',
#  'PAB10888',
#  'PAB10846',
#  'PAB10858',
#  'PAB10873',
#  'PAB10849',
#  'PAB10891',
#  'PAB10855',
#  'PAB10861',
#  'PAB10886',
#  'PAB10856',
#  'PAB10850',
#  'PAB10868',
#  'PAB10844',
#  'A010-25MG',
#  'A010-10MG',
#  '613-741-168',
#  'PAB10901',
#  'PAB10895',
#  'PAB10902',
#  'PAB10896',
#  '613-742-168',
#  '613-743-168',
#  '613-744-168',
#  '613-745-168',
#  'PAB10899',
#  'PAB10893',
#  'PAB10900',
#  'PAB10894',
#  'PAB10903',
#  'PAB10897',
#  'PAB10898',
#  'PAB10892',
#  '619-100-002',
#  '803-1102',
#  '803-4102',
#  '803-1602',
#  '803-4602',
#  '803-1202',
#  '803-4202',
#  '803-1302',
#  '803-4302',
#  'PAB29160',
#  'PAB29161',
#  'PAB29162',
#  'PAB29163',
#  'PAB29164',
#  '605-441-003',
#  '605-442-003',
#  '605-444-003',
#  '610-144-003',
#  '610-141-003',
#  '610-142-003',
#  '611-141-003',
#  '611-142-003',
#  '611-144-003',
#  '700-101-096',
#  '700-105-096',
#  '700-106-096',
#  '700-103-096',
#  '700-100-096',
#  'CLAS10-943',
#  'CLAS10-1061',
#  'CLAS10-1154',
#  'CLAS10-1058',
#  'CLAS10-997',
#  'CLAS10-1037',
#  'CLAS10-659',
#  'CLAS10-960',
#  'CLAS10-1077',
#  'CLAS10-1064',
#  'CLAS10-1271',
#  'CLAS10-1065',
#  'CLAS10-657',
#  'CLAS10-1155',
#  'CLAS10-1045',
#  'CLAS10-980',
#  'CLAS09-612',
#  'CLAS10-658',
#  'CLAS10-1056',
#  'CLAS10-1265',
#  'CLAS10-1300',
#  'CLAS09-630',
#  'CLAS10-1101',
#  'CLAS09-605',
#  '605-309-002',
#  '605-303-002',
#  '605-305-002',
#  '605-306-002',
#  '605-302-002',
#  '605-301-002',
#  '605-300-002',
#  '23771-2',
#  'PAB10685',
#  '609-302-002',
#  'PAB10709',
#  '23778-1',
#  'PAB10691',
#  '23782-1',
#  '609-303-002',
#  'PAB10728',
#  'PAB10710',
#  'PAB10686',
#  'PAB10692',
#  'PAB10680',
#  '23780-1',
#  '23773-2',
#  '609-309-002',
#  'PAB10713',
#  'PAB10695',
#  'PAB10731',
#  'PAB10689',
#  'PAB10683',
#  'PAB10690',
#  'PAB10708',
#  'PAB10684',
#  '23772-2',
#  'PAB10726',
#  '23786-2',
#  '609-300-002',
#  'PAB10678',
#  '23779-1',
#  '23798-1',
#  '23811-1',
#  '23818-1',
#  'PAB10765',
#  'PAB10741',
#  '23804-1',
#  'PAB10783',
#  'PAB10747',
#  'PAB10735',
#  '23795-2',
#  '23809-2',
#  'PAB10784',
#  'PAB10748',
#  'PAB10766',
#  'PAB10742',
#  'PAB10736',
#  '610-741-124',
#  '610-642-002',
#  '610-442-020',
#  '610-742-124',
#  '605-746-002',
#  '605-446-002-0.5',
#  '605-446-013',
#  '605-746-125',
#  '605-441-002-0.5',
#  '605-741-002-0.5',
#  '605-442-002-0.5',
#  '605-742-002-0.5',
#  '605-443-002-0.5',
#  '605-444-002-0.5',
#  '605-745-002-0.5',
#  '605-445-002-0.5',
#  '605-4313-0100',
#  '605-446-003',
#  'CLAS10-995',
#  'CLAS10-1254',
#  'CLAS10-1241',
#  'CLAS10-953',
#  'CLAS10-1003',
#  'CLAS10-1100',
#  'CLAS10-1249',
#  '606-701-C36',
#  '606-705-C36',
#  '606-706-C36',
#  '606-702-C36',
#  '606-703-C36',
#  '606-709-C36',
#  '606-700-C36',
#  'CLAS10-1060',
#  '609-445-002',
#  '609-446-002-0.5',
#  '609-446-002',
#  '609-146-002-0.5',
#  '609-146-002',
#  '609-141-002-0.5',
#  '609-441-002',
#  '609-441-002-0.5',
#  '609-141-002',
#  '609-142-002',
#  '609-142-002-0.5',
#  '609-442-002-0.5',
#  '609-442-002',
#  '609-143-002-0.5',
#  '609-443-002',
#  '609-443-002-0.5',
#  '609-143-002',
#  '609-444-002',
#  '609-144-002-0.5',
#  '609-144-002',
#  '609-444-002-0.5',
#  'PAB10811',
#  'PAB10824',
#  'PAB10842',
#  'PAB10818',
#  'PAB10812',
#  '23816-2',
#  '611-741-127',
#  '611-742-127',
#  '611-643-122',
#  '611-743-127',
#  '611-744-127',
#  '611-644-122',
#  '611-745-127',
#  '611-645-122',
#  'PAB10815',
#  'PAB10839',
#  'PAB10809',
#  'PAB10821',
#  'PAB10816',
#  'PAB10822',
#  'PAB10810',
#  'PAB10840',
#  'PAB10825',
#  'PAB10813',
#  'PAB10819',
#  'PAB10843',
#  'PAB10820',
#  'PAB10814',
#  'PAB10808',
#  'PAB10838',
#  'PAB10859',
#  'PAB10853',
#  'PAB10889',
#  'PAB10871',
#  'PAB10847',
#  'PAB10872',
#  'PAB10890',
#  'PAB10854',
#  'PAB10860',
#  'PAB10848',
#  '612-446-026',
#  '612-146-120',
#  '612-441-026',
#  '612-141-120',
#  '612-142-120',
#  '612-442-026',
#  '612-143-120',
#  '612-443-026',
#  '612-144-120',
#  '612-444-026',
#  '606-143-129',
#  'PAB10626',
#  'PAB10627',
#  'PAB10611',
#  'PAB10614',
#  'PAB10630',
#  'PAB10625',
#  'PAB10610',
#  '620-106-440',
#  '620-101-440',
#  '620-143-440',
#  '620-145-440',
#  '707-408-002',
#  'PAB10646',
#  'PAB10663',
#  'PAB10647',
#  'PAB10664',
#  'PAB10661',
#  'PAB10644',
#  'PAB10645',
#  'PAB10662',
#  'PAB10648',
#  'PAB10665',
#  'PAB10660',
#  'PAB10643',
#  '609-301-002',
#  '23784-2',
#  '23770-2',
#  '23776-1',
#  'PAB10681',
#  'PAB10729',
#  'PAB10693',
#  'PAB10687',
#  'PAB10711',
#  '609-305-002',
#  '23790-1',
#  '23783-1',
#  'PAB10730',
#  'PAB10682',
#  'PAB10712',
#  '609-306-002',
#  'PAB10694',
#  '23781-1',
#  '23774-2',
#  '23788-2',
#  '609-146-123',
#  '609-145-123',
#  'PAB10727',
#  '23785-2',
#  'PAB10679',
#  '603-141-126',
#  '603-142-126',
#  '603-142-002-0.5',
#  '603-143-126',
#  '603-143-002-0.5',
#  '603-144-002-0.5',
#  '603-144-126',
#  '603-145-002-0.5',
#  '603-145-126',
#  'PAB10505',
#  'PAB10499',
#  'PAB10500',
#  'PAB10506',
#  'PAB10503',
#  'PAB10509',
#  'PAB10504',
#  'PAB10498',
#  'PAB10537',
#  'PAB10525',
#  'PAB10538',
#  'PAB10526',
#  'PAB10535',
#  'PAB10523',
#  'PAB10524',
#  'PAB10536',
#  'PAB10539',
#  'PAB10527',
#  'PAB10522',
#  'PAB10534',
#  'PAB10559',
#  'PAB10553',
#  'PAB10554',
#  'PAB10560',
#  'PAB10551',
#  'PAB10557',
#  'PAB10558',
#  'PAB10552',
#  'PAB10561',
#  'PAB10555',
#  'PAB10550',
#  'PAB10556',
#  '23756-2',
#  'PAB10571',
#  '23769-1',
#  'PAB10577',
#  'PAB10565',
#  '23762-1',
#  'PAB10578',
#  'PAB10566',
#  'PAB10572',
#  '700-101-098',
#  '700-105-098',
#  '700-102-098',
#  '700-103-098',
#  '700-109-098',
#  '700-100-098',
#  'GA1004',
#  'GA1014',
#  'GA1024',
#  'GA1003',
#  'L100A',
#  'L100B',
#  'L101A',
#  'L101B',
#  'L155A',
#  'L155B',
#  'L103B',
#  'L103A',
#  'L104A',
#  'L104B',
#  'L106A',
#  'L106B',
#  'L107A',
#  'L107B',
#  'L109B',
#  'L109A',
#  'L110A',
#  'L110B',
#  'L156A',
#  'L156B',
#  'L113B',
#  'L113A',
#  'L114B',
#  'L114A',
#  'L157B',
#  'L157A',
#  'L116A',
#  'L116B',
#  'L117B',
#  'L117A',
#  'L119A',
#  'L119B',
#  'L120A',
#  'L120B',
#  'L158B',
#  'L158A',
#  'L122B',
#  'L122A',
#  'L123A',
#  'L123B',
#  '803-4902',
#  '803-1902',
#  '803-1002',
#  '803-4002',
#  'CLCC50000',
#  '805-4102',
#  '605-451-013S',
#  '605-451-013',
#  '605-452-013',
#  '605-452-013S',
#  '605-453-013S',
#  '605-453-013',
#  '605-454-013S',
#  '605-454-013',
#  '605-455-013S',
#  '605-455-013',
#  '605-456-013S',
#  '605-456-013',
#  '605-457-013',
#  '605-457-013S',
#  '805-4602',
#  'CLCC50015',
#  '805-4202',
#  'CLCC50001',
#  'AS-28168-05-H555',
#  '605-708-125',
#  'CLCC50007',
#  '805-4302',
#  'AS-28168',
#  '805-4902',
#  '805-4002',
#  '806-4102',
#  '806-1102',
#  '206-1150',
#  '806-4602',
#  '806-1602',
#  '606-146-129',
#  '606-141-129',
#  '606-142-129',
#  '606-144-129',
#  '606-145-129',
#  '806-4202',
#  '806-1202',
#  '806-1302',
#  '606-103-129',
#  '806-4302',
#  '806-4902',
#  '806-1902',
#  '720-101-440',
#  'CLCC6200',
#  '617-100-006',
#  '610-4106',
#  '610-4506',
#  '610-4606',
#  '610-4206',
#  '610-4306',
#  '610-4906',
#  '610-4006',
#  '612-1106',
#  '612-1506',
#  '612-1606',
#  '612-1206',
#  '612-1306',
#  '612-1906',
#  '612-1006',
#  '11-112-C100',
#  '11-112-C025',
#  '11-326-C100',
#  '11-324-C100',
#  '11-326-C025',
#  '11-324-C025',
#  '11-325-C025',
#  '11-325-C100',
#  '1F-324-C100',
#  '1F-326-C025',
#  '1F-326-C100',
#  '1F-324-C025',
#  '1P-324-C025',
#  '1P-324-C100',
#  '610-105-115',
#  '610-100-115',
#  '11-319-C100',
#  '11-319-C025',
#  '1P-319-C100',
#  '1P-319-C025',
#  '11-536-C025',
#  '11-536-C100',
#  '1F-536-C025',
#  '1F-536-C100',
#  '1X-536-C100',
#  '1X-536-C025',
#  '610-451-C46S',
#  '610-451-C46',
#  '610-452-C46S',
#  '610-452-C46',
#  '610-453-C46S',
#  '610-453-C46',
#  '610-454-C46S',
#  '610-454-C46',
#  '610-455-C46S',
#  '720-105-440',
#  '619-105-002',
#  '720-106-440',
#  'CLCC6215',
#  '619-102-002',
#  '720-102-440',
#  'CLCC6201',
#  '620-142-440',
#  '620-144-440',
#  '620-141-440',
#  '807-4102',
#  '807-1102',
#  '807-4602',
#  '807-1602',
#  '807-4202',
#  '807-1202',
#  '807-1302',
#  '807-4302',
#  '807-4902',
#  '807-1902',
#  'CLCC6204',
#  '720-103-440',
#  'CLCC6207',
#  '619-109-002',
#  '720-109-440',
#  '720-100-440',
#  '708-401-002',
#  '708-405-002',
#  '708-406-002',
#  '708-402-002',
#  '708-408-002',
#  '708-403-002',
#  '708-409-002',
#  '708-400-002',
#  '609-141-123',
#  '609-701-123',
#  '609-701-002',
#  '609-142-123',
#  '809-4102',
#  '709-701-123',
#  '609-144-123',
#  '709-705-123',
#  '709-702-123',
#  '709-703-123',
#  '709-709-123',
#  '709-700-123',
#  '809-1502',
#  '609-705-002',
#  '609-705-123',
#  'PAB10688',
#  '609-706-002',
#  '609-706-123',
#  '809-4602',
#  '609-143-123',
#  '609-702-002',
#  '809-4202',
#  '609-702-123',
#  '609-108-123',
#  'CLCC20004',
#  '609-703-123',
#  '609-703-002',
#  '809-4302',
#  '609-709-123',
#  '809-4902',
#  '609-709-002',
#  '609-700-123',
#  '809-4002',
#  '609-700-002',
#  '810-4102',
#  'CLCC35000',
#  '710-701-124',
#  'CLCC30000',
#  'CLCC30200',
#  '610-151-121',
#  '610-151-121S',
#  '610-152-121S',
#  '610-152-121',
#  '610-153-121',
#  '610-153-121S',
#  '610-154-121',
#  '610-154-121S',
#  '610-155-121S',
#  '610-155-121',
#  '610-156-121',
#  '610-156-121S',
#  '610-157-121S',
#  '610-157-121',
#  'CLCC30008',
#  '710-105-019',
#  '710-705-124',
#  'CLCC30005',
#  '710-106-019',
#  '610-1619-0500',
#  '810-4602',
#  'CLCC35015',
#  'CLCC30215',
#  'CLCC30015',
#  'CLCC35010',
#  'CLCC35011',
#  'CLCC35001',
#  'AS-28176',
#  '811-7902',
#  '811-7002',
#  'CLCC40000',
#  'CLCC40100',
#  '712-101-033',
#  'CLCC40400',
#  '612-151-120',
#  '612-151-120S',
#  '612-152-120S',
#  '612-152-120',
#  '612-153-120S',
#  '612-153-120',
#  '612-154-120S',
#  '612-154-120',
#  '612-155-120S',
#  '612-155-120',
#  '612-156-120S',
#  '612-156-120',
#  '612-157-120',
#  '612-157-120S',
#  '612-705-002',
#  '612-705-120',
#  'CLCC40005',
#  '812-4602',
#  '612-706-002',
#  'CLCC40015',
#  'CLCC40001',
#  'CLCC40101',
#  '612-108-120',
#  'CLCC40004',
#  'CLCC40006',
#  'CLCC40007',
#  '812-4302',
#  'CLCC40003',
#  '612-709-120',
#  '812-4902',
#  '612-709-002',
#  '613-701-168',
#  '813-4102',
#  '613-706-168',
#  '813-7102',
#  '613-705-168',
#  '813-7602',
#  '813-4602',
#  '813-4202',
#  '813-7202',
#  '813-4302',
#  '613-703-168',
#  '813-7302',
#  '710-702-124',
#  '610-1202-0500',
#  '810-4202',
#  'CLCC30201',
#  '610-108-121',
#  'CLCC35004',
#  'CLCC30204',
#  '710-703-124',
#  '810-4302',
#  'CLCC30207',
#  'CLCC30007',
#  'CLCC35007',
#  '610-1319-0500',
#  '710-103-019',
#  'AS-28164',
#  '710-109-019',
#  '710-709-124',
#  '810-4902',
#  '810-4002',
#  '710-700-124',
#  '710-100-019',
#  'CLCC43000',
#  'CLCC42000',
#  '811-7102',
#  '611-151-122',
#  '611-151-122S',
#  '611-152-122S',
#  '611-152-122',
#  '611-153-122',
#  '611-153-122S',
#  '611-154-122',
#  '611-154-122S',
#  '611-155-122S',
#  '611-155-122',
#  '611-156-122',
#  '611-156-122S',
#  '611-157-122',
#  '611-157-122S',
#  '611-106-B76',
#  '811-7602',
#  'CLCC42015',
#  'CLCC43015',
#  'AS-28176-1-FITC',
#  '811-7202',
#  'CLCC42001',
#  'AS-61056-05-H555',
#  '611-108-122',
#  'CLCC42004',
#  'CLCC43007',
#  '811-7302',
#  ...]

# %%
# Out:
# 4742

# %%
# Out:
# 4734

# %%
d_links
# Out:
# ['L125A',
#  'L125B',
#  'L126A',
#  'L126B',
#  'L159B',
#  'L159A',
#  'L128A',
#  'L128B',
#  'L129B',
#  'L129A',
#  'L131B',
#  'L131A',
#  'L132B',
#  'L132A',
#  '612-101-033',
#  '201-4633S',
#  '23865-5',
#  '23867-5',
#  '600-142-098',
#  '800-102-098',
#  '800-103-098',
#  '701-401-002',
#  '701-405-002',
#  '701-406-002',
#  '701-402-002',
#  '701-408-002',
#  '701-403-002',
#  '701-409-002',
#  '701-400-002',
#  '702-403-002',
#  '603-705-C37',
#  '603-706-C37',
#  '603-446-002-0.5',
#  '603-441-002-0.5',
#  '603-442-002-0.5',
#  '603-443-002-0.5',
#  '603-444-002-0.5',
#  '603-445-002-0.5',
#  '603-702-C37',
#  '603-4302-0500',
#  '603-703-C37',
#  '603-4202-0500',
#  '603-709-C37',
#  '603-700-C37',
#  '346022-1ML',
#  'CLAS99-003',
#  '603-701-C37',
#  'PAB29157',
#  'PAB29158',
#  'PAB29159',
#  '610-455-C46',
#  '610-456-C46S',
#  '610-456-C46',
#  '610-457-C46S',
#  '610-457-C46',
#  '609-1112',
#  '609-4112',
#  '609-1612',
#  '609-4612',
#  '609-4212',
#  '609-4312',
#  '609-4912',
#  '609-1912',
#  '610-146-121',
#  '610-746-124',
#  '610-446-020',
#  '610-646-002',
#  '611-146-122',
#  '611-746-127',
#  '611-646-122',
#  '603-446-002',
#  '603-441-002',
#  '603-442-002',
#  '603-443-002',
#  '603-444-002',
#  '603-445-002',
#  '605-446-002',
#  '605-441-002',
#  '605-442-002',
#  '605-443-002',
#  '605-444-002',
#  '605-445-002',
#  '610-746-002',
#  '610-446-002',
#  '610-641-002',
#  '610-441-002',
#  '610-741-002',
#  '610-742-002',
#  '610-442-002',
#  '610-743-002',
#  '610-443-002',
#  '610-444-002',
#  '610-744-002',
#  '610-445-002',
#  '610-745-002',
#  '611-146-002',
#  '611-141-002',
#  '611-142-002',
#  '611-143-002',
#  '611-144-002',
#  '23760-2',
#  '605-746-002-0.5',
#  '605-741-002',
#  '605-741-125',
#  '605-742-125',
#  '605-742-002',
#  '605-743-002',
#  '605-743-125',
#  '605-443-013',
#  '605-743-002-0.5',
#  '605-744-002-0.5',
#  '605-744-002',
#  '605-744-125',
#  '605-444-013',
#  '605-745-125',
#  '605-745-002',
#  '605-445-013',
#  'PAB10569',
#  'PAB10575',
#  '23757-2',
#  'PAB10563',
#  'PAB10576',
#  'PAB10570',
#  '23766-1',
#  '23759-2',
#  'PAB10567',
#  'PAB10573',
#  'PAB10579',
#  'PAB10568',
#  'PAB10574',
#  '23758-2',
#  '23765-1',
#  'PAB10562',
#  '620-146-440',
#  'PAB10601',
#  'PAB10595',
#  'PAB10596',
#  'PAB10602',
#  'PAB10593',
#  'PAB10599',
#  'PAB10600',
#  'PAB10594',
#  'PAB10597',
#  'PAB10603',
#  'PAB10592',
#  'PAB10598',
#  'PAB10628',
#  'PAB10612',
#  'PAB10613',
#  'PAB10629',
#  '611-145-002',
#  '612-446-002',
#  '612-441-002',
#  '612-442-002',
#  '612-443-002',
#  '612-444-002',
#  '612-445-002',
#  '613-446-002',
#  '613-441-002',
#  '613-442-002',
#  '613-443-002',
#  '613-444-002',
#  '613-445-002',
#  'PAB10427',
#  'PAB10428',
#  'PAB10425',
#  'PAB10426',
#  'PAB10429',
#  'PAB10424',
#  'PAB10449',
#  'PAB10434',
#  'PAB10450',
#  'PAB10447',
#  'PAB10448',
#  'PAB10432',
#  'PAB10435',
#  'PAB10451',
#  'PAB10446',
#  'PAB10467',
#  'PAB10484',
#  'PAB10485',
#  'PAB10465',
#  'PAB10482',
#  'PAB10466',
#  'PAB10483',
#  'PAB10468',
#  'PAB10464',
#  'PAB10481',
#  '603-146-002',
#  '603-141-002',
#  '603-142-002',
#  '603-143-002',
#  '603-145-002',
#  'PAB10501',
#  'PAB10507',
#  'PAB10508',
#  'PAB10502',
#  '603-146-126',
#  '603-146-002-0.5',
#  '603-141-002-0.5',
#  '609-145-002-0.5',
#  '609-145-002',
#  '609-445-002-0.5',
#  '609-1316-0100',
#  '209-301-003',
#  'CL6002',
#  'CL6002F',
#  'CL6100',
#  'CL6200',
#  'CL6200F',
#  'CL6100F',
#  'CLF001AP',
#  'CLF001F',
#  'CLF004',
#  'CLF003AP',
#  '11-322-C100',
#  '11-322-C025',
#  '618-106-006',
#  '618-101-006',
#  '618-105-006',
#  '618-102-006',
#  '618-103-006',
#  '618-109-006',
#  '618-100-006',
#  '709-1106',
#  '609-1106',
#  '609-4106',
#  '609-4506',
#  '609-1506',
#  '709-1506',
#  '609-1606',
#  '709-1606',
#  '609-4606',
#  '609-1206',
#  '609-4206',
#  '709-1206',
#  '609-4306',
#  '709-1306',
#  '609-1306',
#  '609-1906',
#  '609-4906',
#  '709-1006',
#  '609-4006',
#  '609-1006',
#  '617-101-006',
#  '617-105-006',
#  '617-106-006',
#  '617-102-006',
#  '617-103-006',
#  '617-109-006',
#  '610-743-124',
#  '610-643-002',
#  '610-443-020',
#  '610-744-124',
#  '610-644-002',
#  '610-444-020',
#  '610-645-002',
#  '610-445-020',
#  '610-745-124',
#  '610-145-002',
#  '23806-2',
#  'PAB10745',
#  'PAB10739',
#  'PAB10781',
#  'PAB10733',
#  'PAB10763',
#  'PAB10782',
#  'PAB10764',
#  'PAB10746',
#  '23810-2',
#  '23817-2',
#  'PAB10734',
#  '23796-2',
#  '23803-1',
#  'PAB10740',
#  '23815-2',
#  'PAB10749',
#  'PAB10737',
#  'PAB10785',
#  'PAB10767',
#  'PAB10743',
#  'PAB10744',
#  'PAB10780',
#  'PAB10732',
#  'PAB10762',
#  'PAB10738',
#  'PAB10795',
#  'PAB10789',
#  'PAB10796',
#  'PAB10790',
#  'PAB10787',
#  'PAB10793',
#  'PAB10788',
#  'PAB10794',
#  'PAB10791',
#  'PAB10792',
#  'PAB10786',
#  'PAB10841',
#  'PAB10817',
#  'PAB10823',
#  '612-445-026',
#  '612-145-120',
#  'PAB10887',
#  'PAB10845',
#  'PAB10851',
#  'PAB10869',
#  'PAB10857',
#  'PAB10852',
#  'PAB10870',
#  'PAB10888',
#  'PAB10846',
#  'PAB10858',
#  'PAB10873',
#  'PAB10849',
#  'PAB10891',
#  'PAB10855',
#  'PAB10861',
#  'PAB10886',
#  'PAB10856',
#  'PAB10850',
#  'PAB10868',
#  'PAB10844',
#  'A010-25MG',
#  'A010-10MG',
#  '613-741-168',
#  'PAB10901',
#  'PAB10895',
#  'PAB10902',
#  'PAB10896',
#  '613-742-168',
#  '613-743-168',
#  '613-744-168',
#  '613-745-168',
#  'PAB10899',
#  'PAB10893',
#  'PAB10900',
#  'PAB10894',
#  'PAB10903',
#  'PAB10897',
#  'PAB10898',
#  'PAB10892',
#  '619-100-002',
#  '803-1102',
#  '803-4102',
#  '803-1602',
#  '803-4602',
#  '803-1202',
#  '803-4202',
#  '803-1302',
#  '803-4302',
#  'PAB29160',
#  'PAB29161',
#  'PAB29162',
#  'PAB29163',
#  'PAB29164',
#  '605-441-003',
#  '605-442-003',
#  '605-444-003',
#  '610-144-003',
#  '610-141-003',
#  '610-142-003',
#  '611-141-003',
#  '611-142-003',
#  '611-144-003',
#  '700-101-096',
#  '700-105-096',
#  '700-106-096',
#  '700-103-096',
#  '700-100-096',
#  'CLAS10-943',
#  'CLAS10-1061',
#  'CLAS10-1154',
#  'CLAS10-1058',
#  'CLAS10-997',
#  'CLAS10-1037',
#  'CLAS10-659',
#  'CLAS10-960',
#  'CLAS10-1077',
#  'CLAS10-1064',
#  'CLAS10-1271',
#  'CLAS10-1065',
#  'CLAS10-657',
#  'CLAS10-1155',
#  'CLAS10-1045',
#  'CLAS10-980',
#  'CLAS09-612',
#  'CLAS10-658',
#  'CLAS10-1056',
#  'CLAS10-1265',
#  'CLAS10-1300',
#  'CLAS09-630',
#  'CLAS10-1101',
#  'CLAS09-605',
#  '605-309-002',
#  '605-303-002',
#  '605-305-002',
#  '605-306-002',
#  '605-302-002',
#  '605-301-002',
#  '605-300-002',
#  '23771-2',
#  'PAB10685',
#  '609-302-002',
#  'PAB10709',
#  '23778-1',
#  'PAB10691',
#  '23782-1',
#  '609-303-002',
#  'PAB10728',
#  'PAB10710',
#  'PAB10686',
#  'PAB10692',
#  'PAB10680',
#  '23780-1',
#  '23773-2',
#  '609-309-002',
#  'PAB10713',
#  'PAB10695',
#  'PAB10731',
#  'PAB10689',
#  'PAB10683',
#  'PAB10690',
#  'PAB10708',
#  'PAB10684',
#  '23772-2',
#  'PAB10726',
#  '23786-2',
#  '609-300-002',
#  'PAB10678',
#  '23779-1',
#  '23798-1',
#  '23811-1',
#  '23818-1',
#  'PAB10765',
#  'PAB10741',
#  '23804-1',
#  'PAB10783',
#  'PAB10747',
#  'PAB10735',
#  '23795-2',
#  '23809-2',
#  'PAB10784',
#  'PAB10748',
#  'PAB10766',
#  'PAB10742',
#  'PAB10736',
#  '610-741-124',
#  '610-642-002',
#  '610-442-020',
#  '610-742-124',
#  '605-746-002',
#  '605-446-002-0.5',
#  '605-446-013',
#  '605-746-125',
#  '605-441-002-0.5',
#  '605-741-002-0.5',
#  '605-442-002-0.5',
#  '605-742-002-0.5',
#  '605-443-002-0.5',
#  '605-444-002-0.5',
#  '605-745-002-0.5',
#  '605-445-002-0.5',
#  '605-4313-0100',
#  '605-446-003',
#  'CLAS10-995',
#  'CLAS10-1254',
#  'CLAS10-1241',
#  'CLAS10-953',
#  'CLAS10-1003',
#  'CLAS10-1100',
#  'CLAS10-1249',
#  '606-701-C36',
#  '606-705-C36',
#  '606-706-C36',
#  '606-702-C36',
#  '606-703-C36',
#  '606-709-C36',
#  '606-700-C36',
#  'CLAS10-1060',
#  '609-445-002',
#  '609-446-002-0.5',
#  '609-446-002',
#  '609-146-002-0.5',
#  '609-146-002',
#  '609-141-002-0.5',
#  '609-441-002',
#  '609-441-002-0.5',
#  '609-141-002',
#  '609-142-002',
#  '609-142-002-0.5',
#  '609-442-002-0.5',
#  '609-442-002',
#  '609-143-002-0.5',
#  '609-443-002',
#  '609-443-002-0.5',
#  '609-143-002',
#  '609-444-002',
#  '609-144-002-0.5',
#  '609-144-002',
#  '609-444-002-0.5',
#  'PAB10811',
#  'PAB10824',
#  'PAB10842',
#  'PAB10818',
#  'PAB10812',
#  '23816-2',
#  '611-741-127',
#  '611-742-127',
#  '611-643-122',
#  '611-743-127',
#  '611-744-127',
#  '611-644-122',
#  '611-745-127',
#  '611-645-122',
#  'PAB10815',
#  'PAB10839',
#  'PAB10809',
#  'PAB10821',
#  'PAB10816',
#  'PAB10822',
#  'PAB10810',
#  'PAB10840',
#  'PAB10825',
#  'PAB10813',
#  'PAB10819',
#  'PAB10843',
#  'PAB10820',
#  'PAB10814',
#  'PAB10808',
#  'PAB10838',
#  'PAB10859',
#  'PAB10853',
#  'PAB10889',
#  'PAB10871',
#  'PAB10847',
#  'PAB10872',
#  'PAB10890',
#  'PAB10854',
#  'PAB10860',
#  'PAB10848',
#  '612-446-026',
#  '612-146-120',
#  '612-441-026',
#  '612-141-120',
#  '612-142-120',
#  '612-442-026',
#  '612-143-120',
#  '612-443-026',
#  '612-144-120',
#  '612-444-026',
#  '606-143-129',
#  'PAB10626',
#  'PAB10627',
#  'PAB10611',
#  'PAB10614',
#  'PAB10630',
#  'PAB10625',
#  'PAB10610',
#  '620-106-440',
#  '620-101-440',
#  '620-143-440',
#  '620-145-440',
#  '707-408-002',
#  'PAB10646',
#  'PAB10663',
#  'PAB10647',
#  'PAB10664',
#  'PAB10661',
#  'PAB10644',
#  'PAB10645',
#  'PAB10662',
#  'PAB10648',
#  'PAB10665',
#  'PAB10660',
#  'PAB10643',
#  '609-301-002',
#  '23784-2',
#  '23770-2',
#  '23776-1',
#  'PAB10681',
#  'PAB10729',
#  'PAB10693',
#  'PAB10687',
#  'PAB10711',
#  '609-305-002',
#  '23790-1',
#  '23783-1',
#  'PAB10730',
#  'PAB10682',
#  'PAB10712',
#  '609-306-002',
#  'PAB10694',
#  '23781-1',
#  '23774-2',
#  '23788-2',
#  '609-146-123',
#  '609-145-123',
#  'PAB10727',
#  '23785-2',
#  'PAB10679',
#  '603-141-126',
#  '603-142-126',
#  '603-142-002-0.5',
#  '603-143-126',
#  '603-143-002-0.5',
#  '603-144-002-0.5',
#  '603-144-126',
#  '603-145-002-0.5',
#  '603-145-126',
#  'PAB10505',
#  'PAB10499',
#  'PAB10500',
#  'PAB10506',
#  'PAB10503',
#  'PAB10509',
#  'PAB10504',
#  'PAB10498',
#  'PAB10537',
#  'PAB10525',
#  'PAB10538',
#  'PAB10526',
#  'PAB10535',
#  'PAB10523',
#  'PAB10524',
#  'PAB10536',
#  'PAB10539',
#  'PAB10527',
#  'PAB10522',
#  'PAB10534',
#  'PAB10559',
#  'PAB10553',
#  'PAB10554',
#  'PAB10560',
#  'PAB10551',
#  'PAB10557',
#  'PAB10558',
#  'PAB10552',
#  'PAB10561',
#  'PAB10555',
#  'PAB10550',
#  'PAB10556',
#  '23756-2',
#  'PAB10571',
#  '23769-1',
#  'PAB10577',
#  'PAB10565',
#  '23762-1',
#  'PAB10578',
#  'PAB10566',
#  'PAB10572',
#  '700-101-098',
#  '700-105-098',
#  '700-102-098',
#  '700-103-098',
#  '700-109-098',
#  '700-100-098',
#  'GA1024',
#  'L100A',
#  'L100B',
#  'L101A',
#  'L101B',
#  'L155A',
#  'L155B',
#  'L103B',
#  'L103A',
#  'L104A',
#  'L104B',
#  'L106A',
#  'L106B',
#  'L107A',
#  'L107B',
#  'L109B',
#  'L109A',
#  'L110A',
#  'L110B',
#  'L156A',
#  'L156B',
#  'L113B',
#  'L113A',
#  'L114B',
#  'L114A',
#  'L157B',
#  'L157A',
#  'L116A',
#  'L116B',
#  'L117B',
#  'L117A',
#  'L119A',
#  'L119B',
#  'L120A',
#  'L120B',
#  'L158B',
#  'L158A',
#  'L122B',
#  'L122A',
#  'L123A',
#  'L123B',
#  '803-4902',
#  '803-1902',
#  '803-1002',
#  '803-4002',
#  'CLCC50000',
#  '805-4102',
#  '605-451-013S',
#  '605-451-013',
#  '605-452-013',
#  '605-452-013S',
#  '605-453-013S',
#  '605-453-013',
#  '605-454-013S',
#  '605-454-013',
#  '605-455-013S',
#  '605-455-013',
#  '605-456-013S',
#  '605-456-013',
#  '605-457-013',
#  '605-457-013S',
#  '805-4602',
#  'CLCC50015',
#  '805-4202',
#  'CLCC50001',
#  'AS-28168-05-H555',
#  '605-708-125',
#  'CLCC50007',
#  '805-4302',
#  'AS-28168',
#  '805-4902',
#  '805-4002',
#  '806-4102',
#  '806-1102',
#  '206-1150',
#  '806-4602',
#  '806-1602',
#  '606-146-129',
#  '606-141-129',
#  '606-142-129',
#  '606-144-129',
#  '606-145-129',
#  '806-4202',
#  '806-1202',
#  '806-1302',
#  '606-103-129',
#  '806-4302',
#  '806-4902',
#  '806-1902',
#  '720-101-440',
#  'CLCC6200',
#  '617-100-006',
#  '610-4106',
#  '610-4506',
#  '610-4606',
#  '610-4206',
#  '610-4306',
#  '610-4906',
#  '610-4006',
#  '612-1106',
#  '612-1506',
#  '612-1606',
#  '612-1206',
#  '612-1306',
#  '612-1906',
#  '612-1006',
#  '11-112-C100',
#  '11-112-C025',
#  '11-326-C100',
#  '11-324-C100',
#  '11-326-C025',
#  '11-324-C025',
#  '11-325-C025',
#  '11-325-C100',
#  '1F-324-C100',
#  '1F-326-C025',
#  '1F-326-C100',
#  '1F-324-C025',
#  '1P-324-C025',
#  '1P-324-C100',
#  '610-105-115',
#  '610-100-115',
#  '11-319-C100',
#  '11-319-C025',
#  '1P-319-C100',
#  '1P-319-C025',
#  '11-536-C025',
#  '11-536-C100',
#  '1F-536-C025',
#  '1F-536-C100',
#  '1X-536-C100',
#  '1X-536-C025',
#  '610-451-C46S',
#  '610-451-C46',
#  '610-452-C46S',
#  '610-452-C46',
#  '610-453-C46S',
#  '610-453-C46',
#  '610-454-C46S',
#  '610-454-C46',
#  '610-455-C46S',
#  '720-105-440',
#  '619-105-002',
#  '720-106-440',
#  'CLCC6215',
#  '619-102-002',
#  '720-102-440',
#  'CLCC6201',
#  '620-142-440',
#  '620-144-440',
#  '620-141-440',
#  '807-4102',
#  '807-1102',
#  '807-4602',
#  '807-1602',
#  '807-4202',
#  '807-1202',
#  '807-1302',
#  '807-4302',
#  '807-4902',
#  '807-1902',
#  'CLCC6204',
#  '720-103-440',
#  'CLCC6207',
#  '619-109-002',
#  '720-109-440',
#  '720-100-440',
#  '708-401-002',
#  '708-405-002',
#  '708-406-002',
#  '708-402-002',
#  '708-408-002',
#  '708-403-002',
#  '708-409-002',
#  '708-400-002',
#  '609-141-123',
#  '609-701-123',
#  '609-701-002',
#  '609-142-123',
#  '809-4102',
#  '709-701-123',
#  '609-144-123',
#  '709-705-123',
#  '709-702-123',
#  '709-703-123',
#  '709-709-123',
#  '709-700-123',
#  '809-1502',
#  '609-705-002',
#  '609-705-123',
#  'PAB10688',
#  '609-706-002',
#  '609-706-123',
#  '809-4602',
#  '609-143-123',
#  '609-702-002',
#  '809-4202',
#  '609-702-123',
#  '609-108-123',
#  'CLCC20004',
#  '609-703-123',
#  '609-703-002',
#  '809-4302',
#  '609-709-123',
#  '809-4902',
#  '609-709-002',
#  '609-700-123',
#  '809-4002',
#  '609-700-002',
#  '810-4102',
#  'CLCC35000',
#  '710-701-124',
#  'CLCC30000',
#  'CLCC30200',
#  '610-151-121',
#  '610-151-121S',
#  '610-152-121S',
#  '610-152-121',
#  '610-153-121',
#  '610-153-121S',
#  '610-154-121',
#  '610-154-121S',
#  '610-155-121S',
#  '610-155-121',
#  '610-156-121',
#  '610-156-121S',
#  '610-157-121S',
#  '610-157-121',
#  'CLCC30008',
#  '710-105-019',
#  '710-705-124',
#  'CLCC30005',
#  '710-106-019',
#  '610-1619-0500',
#  '810-4602',
#  'CLCC35015',
#  'CLCC30215',
#  'CLCC30015',
#  'CLCC35010',
#  'CLCC35011',
#  'CLCC35001',
#  'AS-28176',
#  '811-7902',
#  '811-7002',
#  'CLCC40000',
#  'CLCC40100',
#  '712-101-033',
#  'CLCC40400',
#  '612-151-120',
#  '612-151-120S',
#  '612-152-120S',
#  '612-152-120',
#  '612-153-120S',
#  '612-153-120',
#  '612-154-120S',
#  '612-154-120',
#  '612-155-120S',
#  '612-155-120',
#  '612-156-120S',
#  '612-156-120',
#  '612-157-120',
#  '612-157-120S',
#  '612-705-002',
#  '612-705-120',
#  'CLCC40005',
#  '812-4602',
#  '612-706-002',
#  'CLCC40015',
#  'CLCC40001',
#  'CLCC40101',
#  '612-108-120',
#  'CLCC40004',
#  'CLCC40006',
#  'CLCC40007',
#  '812-4302',
#  'CLCC40003',
#  '612-709-120',
#  '812-4902',
#  '612-709-002',
#  '613-701-168',
#  '813-4102',
#  '613-706-168',
#  '813-7102',
#  '613-705-168',
#  '813-7602',
#  '813-4602',
#  '813-4202',
#  '813-7202',
#  '813-4302',
#  '613-703-168',
#  '813-7302',
#  '710-702-124',
#  '610-1202-0500',
#  '810-4202',
#  'CLCC30201',
#  '610-108-121',
#  'CLCC35004',
#  'CLCC30204',
#  '710-703-124',
#  '810-4302',
#  'CLCC30207',
#  'CLCC30007',
#  'CLCC35007',
#  '610-1319-0500',
#  '710-103-019',
#  'AS-28164',
#  '710-109-019',
#  '710-709-124',
#  '810-4902',
#  '810-4002',
#  '710-700-124',
#  '710-100-019',
#  'CLCC43000',
#  'CLCC42000',
#  '811-7102',
#  '611-151-122',
#  '611-151-122S',
#  '611-152-122S',
#  '611-152-122',
#  '611-153-122',
#  '611-153-122S',
#  '611-154-122',
#  '611-154-122S',
#  '611-155-122S',
#  '611-155-122',
#  '611-156-122',
#  '611-156-122S',
#  '611-157-122',
#  '611-157-122S',
#  '611-106-B76',
#  '811-7602',
#  'CLCC42015',
#  'CLCC43015',
#  'AS-28176-1-FITC',
#  '811-7202',
#  'CLCC42001',
#  'AS-61056-05-H555',
#  '611-108-122',
#  'CLCC42004',
#  'CLCC43007',
#  '811-7302',
#  'PAB10474',
#  'PAB10491',
#  'PAB10486',
#  ...]

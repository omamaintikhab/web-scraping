# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile

# %%
data=pd.read_excel("ITK_Alpha_newproducts.xlsx")
article_number=list(data["Article number"])
#article_number[0]

# %%
article_number=list(data["Article number"])
#article_number[0]

# %%
s="https://www.4adi.com/render.cz?method=searchProducts&categoryId=&keywords=HEPC13-S"
source=requests.get(s).text
soup=BeautifulSoup(source,'lxml')
table=soup.findAll("table")
j=[]
links=[]
for tab in table:
    tr=tab.findAll("tr",{"class":"item"})
    for t in tr:
        if len(t)>0:
            td=t.findAll("td")
            alpha=[]
            for xx in td:
                j.append(xx.text)
                
                a_tag=xx.findAll('a')
                for a in a_tag:
                    
                    if len(a)>0:
                        alpha.append(a['href'])
                        
            links.append(alpha[0])    
        
j
# Out:
# ['\nHEPC13-S\n',
#  '\nAnti-Mouse/Human Hepcidin-25 antiserum # 3\n',
#  '\r\n\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\tPrimary Antibodies\r\n\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t',
#  '\n\n\n\n',
#  '\n100 ul\n',
#  '\n\r\n\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t335.0\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n']

# %%
name_specs=[]
for i in j:
    if '\n' in i or '\t':
        i=i.split()
        i=' '.join(i)
    name_specs.append(i)
name_specs
# Out:
# ['HEPC13-S',
#  'Anti-Mouse/Human Hepcidin-25 antiserum # 3',
#  'Primary Antibodies',
#  '',
#  '100 ul',
#  '335.0']

# %%
s="https://www.4adi.com/"+links[0]
source=requests.get(s).text
soup=BeautifulSoup(source,'lxml')
table=soup.findAll('table')
table=table[1]
row=table.findAll("tr")
row_info=[]
for r in row:
    info=[]
    td=r.findAll("td")
    for g in td:
        info.append(g.text)
    row_info.append(info)
    #row_info.append({g[0]:g[1]})    
row_info
# Out:
# [['Antigen',
#   'A 7-aa peptide sequences from the N-terminus of mature human and mouse 25-aa HEPC  were synthesized.  The two peptides (designated HEPC13-P or control peptide) conjugated to KLH'],
#  ['Form', 'Antiserum Unpurified'],
#  ['Product Type', 'Primary Antibodies'],
#  ['SpCrossreactivity',
#   'The mouse HEPC13-P sequences from mouse/rat, and human differ by just aa in 25-aa mature HEPC.  The HEPC13-P sequence is truncated by 5-aa in the 20-aa major secreted HEPC.  Anti-HEPC13-P do not have significant reactivity with 20-aa HEPC peptide.  Anti-HEPC13-P could potentially react with the unprocessed larger 60-aa pro-HEPC if present in the samples or tissues.  Antibody cross-reactivity in various species has not been studied.  Full length, human 25-aa (cat # HEPC61-P) and 20-aa HEPC (cat # HEPC71-P) and mouse 25-aa HEPC (cat # HEPC-81) are also available for various studies'],
#  ['SpeciesReactivity', 'Mouse/Human'],
#  ['SugApplications',
# ...

# %%
data_list=[]
for i in row_info:
    data=i[0]
    description=i[1]
    data_list.append({data:description})

# %%
data_list
# Out:
# [{'Antigen': 'A 7-aa peptide sequences from the N-terminus of mature human and mouse 25-aa HEPC  were synthesized.  The two peptides (designated HEPC13-P or control peptide) conjugated to KLH'},
#  {'Form': 'Antiserum Unpurified'},
#  {'Product Type': 'Primary Antibodies'},
#  {'SpCrossreactivity': 'The mouse HEPC13-P sequences from mouse/rat, and human differ by just aa in 25-aa mature HEPC.  The HEPC13-P sequence is truncated by 5-aa in the 20-aa major secreted HEPC.  Anti-HEPC13-P do not have significant reactivity with 20-aa HEPC peptide.  Anti-HEPC13-P could potentially react with the unprocessed larger 60-aa pro-HEPC if present in the samples or tissues.  Antibody cross-reactivity in various species has not been studied.  Full length, human 25-aa (cat # HEPC61-P) and 20-aa HEPC (cat # HEPC71-P) and mouse 25-aa HEPC (cat # HEPC-81) are also available for various studies'},
#  {'SpeciesReactivity': 'Mouse/Human'},
# ...

# %%
combined_list=[name_specs,data_list]
combined_list
# Out:
# [['HEPC13-S',
#   'Anti-Mouse/Human Hepcidin-25 antiserum # 3',
#   'Primary Antibodies',
#   '',
#   '100 ul',
#   '335.0'],
#  [{'Antigen': 'A 7-aa peptide sequences from the N-terminus of mature human and mouse 25-aa HEPC  were synthesized.  The two peptides (designated HEPC13-P or control peptide) conjugated to KLH'},
#   {'Form': 'Antiserum Unpurified'},
#   {'Product Type': 'Primary Antibodies'},
# ...

# %%
article_number=list(data["Article number"])
final_list=[]
count=0
for i in range(len(article_number)):
    count=+1
    print(count)
    combined_list=[]
    s="https://www.4adi.com/render.cz?method=searchProducts&categoryId=&keywords="+article_number[i]
    source=requests.get(s).text
    soup=BeautifulSoup(source,'lxml')
    table=soup.findAll("table")
    j=[]
    links=[]
    for tab in table:
        tr=tab.findAll("tr",{"class":"item"})
        for t in tr:
            if len(t)>0:
                td=t.findAll("td")
                alpha=[]
                for xx in td:
                    j.append(xx.text)

                    a_tag=xx.findAll('a')
                    for a in a_tag:

                        if len(a)>0:
                            alpha.append(a['href'])
                alpha_0=alpha[0]
                print(alpha_0)
                links.append(alpha_0)
    name_specs=[]
    for i in j:
        if '\n' in i or '\t':
            i=i.split()
            i=' '.join(i)
            
                
        name_specs.append(i)
    s="https://www.4adi.com/"+alpha_0
    source=requests.get(s).text
    soup=BeautifulSoup(source,'lxml')
    table=soup.findAll('table')
    table=table[1]
    row=table.findAll("tr")
    row_info=[]
    for r in row:
        
        info=[]
        td=r.findAll("td")
        for g in td:
            info.append(g.text)
        row_info.append(info)
        #row_info.append({g[0]:g[1]})    

    data_list=[]
    for i in row_info:
        
        data=i[0]
        description=i[1]
        data_list.append({data:description})
    combined_list=[name_specs,data_list]
    final_list.append(combined_list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-8d92808baaff> in <module>
# ----> 1 article_number=list(data["Article number"])
#       2 final_list=[]
#       3 count=0
#       4 for i in range(len(article_number)):
#       5     count=+1
#
# TypeError: string indices must be integers

# %%
s="https://www.4adi.com/render.cz?method=searchProducts&categoryId=&keywords=EP11-A"
source=requests.get(s).text
soup=BeautifulSoup(source,'lxml')
table=soup.findAll("table")
j=[]
links=[]
for tab in table:
    tr=tab.findAll("tr",{"class":"item"})
    for t in tr:
        if len(t)>0:
            n=[]
            td=t.findAll("td")
            alpha=[]
            for xx in td:
                n.append(xx.text)
                
                a_tag=xx.findAll('a')
                for a in a_tag:
                    
                    if len(a)>0:
                        alpha.append(a['href'])
            j.append(n)            
            links.append(alpha[0])    
x_r=[]        
for i in range(len(links)):
    data_list=[]
    s="https://www.4adi.com/"+links[i]
    source=requests.get(s).text
    soup=BeautifulSoup(source,'lxml')
    table=soup.findAll('table')
    table=table[1]
    row=table.findAll("tr")
    row_info=[]
    for r in row:
        
        info=[]
        td=r.findAll("td")
        for g in td:
            info.append(g.text)
        row_info.append(info)
    #x_r.append(row_info)
        for r in row_info:
            
            data=r[0]
            description=r[1]
            data_list.append({data:description})
            
    
data_list

# %%
name_specs=[]
d=[]
for i in j:
    for f in i:
        f=f.split()
        f=' '.join(f)
        name_specs.append(f)

# %%
s="https://www.4adi.com/render.cz?method=searchProducts&categoryId=&keywords=EP11-A"
source=requests.get(s).text
soup=BeautifulSoup(source,'lxml')
table=soup.findAll("table")
j=[]
links=[]
urls=[]
pdf_insert=[]
for tab in table:
    table_row=tab.findAll("tr",{"class":"item"})
    x=[]
    for tr in table_row:
        tag_a=tr.findAll('a')
        linker_a=[]
        for a in tag_a:
            linker_a.append(a['href'])
        addrs=linker_a[0]
        urls.append(addrs)
        pdf=linker_a[1]
        pdf_insert.append(pdf)
        
        row_n=[]
        table_td=tr.findAll('td')
        for td in table_td:
            
            row_n.append(td.text)
        #links.append()    
        j.append(row_n)    
    
for s,i in enumerate(j):
    i.append(pdf_insert[s])
all_data=[]  
co=[]
khi=[]
for i in range(len(urls)):
    s="https://www.4adi.com/4adi/"+urls[i]
    source=requests.get(s).text
    soup=BeautifulSoup(source,'lxml')
    table=soup.findAll("table")
    table=table[1]
    row=table.findAll("tr")
    row_info=[]
    for r in row:
        info=[]
        h=[]
        tab_d=r.findAll("td")
        for g in tab_d:
            info.append(g.text)
        row_info.append(info)    
        #data=info[0]
        #description=info[1]
        #b=[data,description]
        #row_info.append(info)
        #print(row_info)
        for i in row_info:
            data=i[0]
            description=i[1]
            h.append({data:description})
        all_data.append(h)    
    #all_data.append(row_info)
    #b=[]
    
    #for i,o in enumerate(all_data):
        
     #   for k in o:
      #      data=k[0]
       #     desc=k[1]
        #    b.append({data:desc})
    #print(b)

# %%
all_data

# %%
b=[]
for i,j in enumerate(all_data):
    for k in j:
        data=k[0]
        desc=k[1]
        b.append({data:desc})
b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-f6e1f4a10354> in <module>
#       1 b=[]
# ----> 2 for i,j in enumerate(all_data):
#       3     for k in j:
#       4         data=k[0]
#       5         desc=k[1]
#
# NameError: name 'all_data' is not defined

# %% [markdown]
# # fetching Page from bs4

# %%
s="https://www.4adi.com/render.cz?method=searchProducts&categoryId=&keywords=EP11-A"
source=requests.get(s).text
soup=BeautifulSoup(source,'lxml')
table=soup.findAll("table")
table=table[1]
table_rows=table.findAll("tr",{"class":"item"})

# %%
links=[]
row_data=[]
for tr in table_rows:
    alpha=[]
    a_tag=tr.findAll('a')
    for a in a_tag:
        
        alpha.append(a["href"])
    links.append(alpha[0])
    tad=[]
    tab_d=tr.findAll("td")
    for td in tab_d:
        tad.append(td.text)
        
    tad.append(alpha[1])
    row_data.append(tad)
        
row_data
# Out:
# [['\nEP11-A\n',
#   '\nAnti-Mouse Prostaglandin E receptor 1 (EP1) IgG #1, aff pure\n',
#   '\r\n\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\tPrimary Antibodies\r\n\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t',
#   '\n\n\n\n',
#   '\n100 ug\n',
#   '\n\r\n\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t355.0\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n',
#   '/product/pdf/EP11-S-A-P.pdf'],
#  ['\nLEP11-A\n',
#   '\nAnti-Mouse Recomb. Leptin Protein IgG # 1, aff pure\n',
#   '\r\n\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\tPrimary Antibodies\r\n\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t',
#   '\n\n\n\n',
#   '\n100 ug\n',
#   '\n\r\n\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t355.0\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n',
#   '/product/pdf/LEP11-S-A-C.pdf'],
#  ['\nNEP11-A\n',
#   '\nAnti-Mouse Neprilysin (NEP) IgG (aff pure)\n',
#   '\r\n\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\tAntibodies\r\n\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t',
#   '\n\n\n\n',
# ...

# %%
s="https://www.4adi.com/4adi/"+urls[0]
source=requests.get(s).text
soup=BeautifulSoup(source,'lxml')
table=soup.findAll("table")
table=table[1]
row=table.findAll("tr")
u=[]
for tr in row:
    h=[]
    td=tr.findAll('td')
    for x in td:
        h.append(x.text)
    data=h[0]
    desc=h[1]
    l={data:desc}
    u.append(l)
    
        
    
row_data[0].append(u)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-ec7ed4e15fdb> in <module>
# ----> 1 s="https://www.4adi.com/4adi/"+urls[0]
#       2 source=requests.get(s).text
#       3 soup=BeautifulSoup(source,'lxml')
#       4 table=soup.findAll("table")
#       5 table=table[1]
#
# NameError: name 'urls' is not defined

# %%
row_data
# Out:
# [['\nEP11-A\n',
#   '\nAnti-Mouse Prostaglandin E receptor 1 (EP1) IgG #1, aff pure\n',
#   '\r\n\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\tPrimary Antibodies\r\n\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t',
#   '\n\n\n\n',
#   '\n100 ug\n',
#   '\n\r\n\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t355.0\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n',
#   '/product/pdf/EP11-S-A-P.pdf'],
#  ['\nLEP11-A\n',
#   '\nAnti-Mouse Recomb. Leptin Protein IgG # 1, aff pure\n',
#   '\r\n\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\tPrimary Antibodies\r\n\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t',
#   '\n\n\n\n',
#   '\n100 ug\n',
#   '\n\r\n\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t355.0\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n',
#   '/product/pdf/LEP11-S-A-C.pdf'],
#  ['\nNEP11-A\n',
#   '\nAnti-Mouse Neprilysin (NEP) IgG (aff pure)\n',
#   '\r\n\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\tAntibodies\r\n\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t',
#   '\n\n\n\n',
# ...

# %%
s="https://www.4adi.com/render.cz?method=searchProducts&categoryId=&keywords=EP11-A"
source=requests.get(s).text
soup=BeautifulSoup(source,'lxml')
soup
table=soup.findAll("table")
table=table[1]
table_rows=table.findAll("tr",{"class":"item"})
links=[]
row_data=[]
for tr in table_rows:
    alpha=[]
    a_tag=tr.findAll('a')
    for a in a_tag:
        
        alpha.append(a["href"])
    links.append(alpha[0])
    tad=[]
    tab_d=tr.findAll("td")
    for td in tab_d:
        tad.append(td.text)
        
    tad.append(alpha[1])
    row_data.append(tad)

for i in range(len(links)):
    s="https://www.4adi.com/4adi/"+urls[i]
    source=requests.get(s).text
    soup=BeautifulSoup(source,'lxml')
    table=soup.findAll("table")
    table=table[1]
    row=table.findAll("tr")
    u=[]
    for tr in row:
        h=[]
        td=tr.findAll('td')
        for x in td:
            row_data[i].append(x.text)
        #data=h[0]
        #desc=h[1]
        #l={data:desc}
        #u.append(h)
    #row_data[i].append(u)    
        
    
#row_data[0]
for t in row_data:
    for n,i in enumerate(t):
        if "\n" in i or "\t" in i:
            i=i.split()
            i=' '.join(i)
            t[n]=i
            
row_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-3c8579f3a312> in <module>
#      24
#      25 for i in range(len(links)):
# ---> 26     s="https://www.4adi.com/4adi/"+urls[i]
#      27     source=requests.get(s).text
#      28     soup=BeautifulSoup(source,'lxml')
#
# NameError: name 'urls' is not defined

# %%
for t in row_data:
    for n,i in enumerate(t):
        if "\n" in i or "\t" in i:
            i=i.split()
            i=' '.join(i)
            t[n]=i
            
row_data

# %%
v=[]
for j,i in enumerate(row_data[1][7:]):
    try:
        
        j=j*2

        #print(i,j)
        data=row_data[1][7:][j]
        desc=row_data[1][7:][j+1]
        v.append({data:desc})

    except :
        pass
        
    
    
v
# Out:
# []

# %%
s="https://www.4adi.com/render.cz?method=searchProducts&categoryId=&keywords=EP11-A"
source=requests.get(s).text
soup=BeautifulSoup(source,'lxml')
thead=soup.findAll('thead')
header=[]
for trr in thead:
    tar=trr.findAll('td')
    for tdd in tar:
        header.append(tdd.text)
for h,i in enumerate(header):
    if '\t' in i or '\n' in i:
        i=i.split()
        i=' '.join(i)
        header[h]=i
header
# Out:
# ['Catalog#', 'Name', 'Product Type', 'Data Sheet', 'Size', 'Price']

# %%
article_number=list(data["Article number"])
for names in range(len(article_number)):
    s="https://www.4adi.com/render.cz?method=searchProducts&categoryId=&keywords=EP11-A"
source=requests.get(s).text
soup=BeautifulSoup(source,'lxml')
soup
table=soup.findAll("table")
table=table[1]
table_rows=table.findAll("tr",{"class":"item"})
links=[]
row_data=[]
for tr in table_rows:
    alpha=[]
    a_tag=tr.findAll('a')
    for a in a_tag:
        
        alpha.append(a["href"])
    links.append(alpha[0])
    tad=[]
    tab_d=tr.findAll("td")
    for td in tab_d:
        tad.append(td.text)
        
    tad.append(alpha[1])
    row_data.append(tad)

for i in range(len(links)):
    s="https://www.4adi.com/4adi/"+urls[i]
    source=requests.get(s).text
    soup=BeautifulSoup(source,'lxml')
    table=soup.findAll("table")
    table=table[1]
    row=table.findAll("tr")
    u=[]
    for tr in row:
        h=[]
        td=tr.findAll('td')
        for x in td:
            row_data[i].append(x.text)
        #data=h[0]
        #desc=h[1]
        #l={data:desc}
        #u.append(h)
    #row_data[i].append(u)    
        
    
#row_data[0]
for t in row_data:
    for n,i in enumerate(t):
        if "\n" in i or "\t" in i:
            i=i.split()
            i=' '.join(i)
            t[n]=i
            
row_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-5df6ae5a857c> in <module>
#      26
#      27 for i in range(len(links)):
# ---> 28     s="https://www.4adi.com/4adi/"+urls[i]
#      29     source=requests.get(s).text
#      30     soup=BeautifulSoup(source,'lxml')
#
# NameError: name 'urls' is not defined

# %%
e=[]
s="https://www.4adi.com/render.cz?method=searchProducts&categoryId=&keywords=EP11-A"
source=requests.get(s).text
soup=BeautifulSoup(source,'lxml')
soup
table=soup.findAll("table")
#tab_1=table[1]
table=table[1]
table_rows=table.findAll("tr",{"class":"item"})
links=[]
row_data=[]
for tr in table_rows:
    alpha=[]
    atag=tr.findAll('a')
    for a in atag:
        alpha.append(a['href'])
    links.append(alpha[0])
    tabd=tr.findAll("td")
    row=[]
    for i in tabd:
        row.append(i.text)
    row.append(alpha[1])
    row_data.append(row)
    

for i in row_data:
    for d,j in enumerate(i):
        if '\t' in j or "\n" in j:
            j=j.split()
            j=' '.join(j)
            i[d]=j
            
for i in range(len(links)):
    s="https://www.4adi.com/4adi/"+links[i]
    source=requests.get(s).text
    soup=BeautifulSoup(source,'lxml')
    table=soup.findAll("table")
    table=table[1]
    rows=table.findAll("tr")
    for r in rows:
        h=[]
        td_m=r.findAll('td')
        for td in td_m:
            row_data[i].append(td.text)
            
for k in row_data:
    e.append(k)
    e=[]

# %%
data=pd.read_excel("ITK_Alpha_newproducts.xlsx")
article_number=list(data["Article number"])
#article_number[0]
def extraction():
    e=[]
    for x in range(len(article_number)):
        s="https://www.4adi.com/render.cz?method=searchProducts&categoryId=&keywords="+article_number[x]
        source=requests.get(s).text
        soup=BeautifulSoup(source,'lxml')
        #soup
        table=soup.findAll("tbody")
        #tab_1=table[1]
        #table=table[1]
        table_rows=table.findAll("tr",{"class":"item"})
        links=[]
        row_data=[]
        for tr in table_rows:
            
            alpha=[]
            atag=tr.findAll('a')
            for a in atag:
                
                alpha.append(a['href'])
            links.append(alpha[0])
            tabd=tr.findAll("td")
            row=[]
            for i in tabd:
                
                row.append(i.text)
            row.append(alpha[1])
            row_data.append(row)
        for i in row_data:
            
            for d,j in enumerate(i):
                

                if '\t' in j or "\n" in j:
                    j=j.split()
                    j=' '.join(j)
                    i[d]=j

        for i in range(len(links)):
            
            
            s="https://www.4adi.com/4adi/"+links[i]
            source=requests.get(s).text
            soup=BeautifulSoup(source,'lxml')
            table=soup.findAll("table")
            table=table[1]
            rows=table.findAll("tr")
            for r in rows:

                h=[]
                td_m=r.findAll('td')
                for td in td_m:
                    

                    row_data[i].append(td.text)
        for i in row_data:
            e.append(i)




    return e

# %%
a=extraction()
print(a)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-95-425deab68ad8> in <module>
# ----> 1 a=extraction()
#       2 print(a)
#
# <ipython-input-94-182bac4e623c> in extraction()
#      12         #tab_1=table[1]
#      13         #table=table[1]
# ---> 14         table_rows=table.findAll("tr",{"class":"item"})
#      15         links=[]
#      16         row_data=[]
#
# D:\anacondas\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    1576     def __getattr__(self, key):
#    1577         raise AttributeError(
# -> 1578             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1579         )
#
# ...

# %%
s="https://www.4adi.com/render.cz?method=searchProducts&categoryId=&keywords=EP11-A"
source=requests.get(s).text
soup=BeautifulSoup(source,'lxml')
        #soup
table_rows=soup.findAll("tr",{"class":"item"})
info=[]
links=[]
u=[]
for i in table_rows:
    row=[]
    alpha=[]
    atag=i.findAll('a')
    for a in atag:
        alpha.append(a['href'])
    links.append(alpha[0])
    td=i.findAll('td')
    for t in td:
        row.append(t.text)
    row.append(alpha[1])    
    info.append(row)    

for i in info:
    
    for d,j in enumerate(i):
        
        if '\t' in j or "\n" in j:
            j=j.split()
            j=' '.join(j)
            i[d]=j

            
for i in range(len(links)):
    
    s="https://www.4adi.com/4adi/"+links[i]
    source=requests.get(s).text
    soup=BeautifulSoup(source,'lxml')
    table=soup.findAll("table")
    table=table[1]
    rows=table.findAll("tr")
    for r in rows:
        
        h=[]
        td_m=r.findAll('td')
        for td in td_m:
            
            info[i].append(td.text)
     
    
        
            
for q in info:
    u.append(q)

# %%
u
# Out:
# [['EP11-A',
#   'Anti-Mouse Prostaglandin E receptor 1 (EP1) IgG #1, aff pure',
#   'Primary Antibodies',
#   '',
#   '100 ug',
#   '355.0',
#   '/product/pdf/EP11-S-A-P.pdf',
#   'Antigen',
#   '15-aa peptide of Mouse EP1; Designated (EP11-P or control peptide). epitope location ~C-terminus, extracellular domain',
#   'Form',
#   'Affinity purified IgG',
#   'Product Type',
#   'Primary Antibodies',
#   'SpCrossreactivity',
#   'The mouse EP11-P control peptide is 100% conserved in rat, 72% in canine and human, 73% in rabbit and ovine EP1. It has no appreciable sequence homology with EP2-4 or other GPCR.  Antibody cross-reactivity in various species is not established.',
#   'SpeciesReactivity',
#   'Mouse',
#   'SugApplications',
# ...

# %%
data=pd.read_excel("ITK_Alpha_newproducts.xlsx")
article_number=list(data["Article number"])

def fun():
    u=[]
    for x in range(len(article_number)):
        s="https://www.4adi.com/render.cz?method=searchProducts&categoryId=&keywords="+article_number[x]
        source=requests.get(s).text
        soup=BeautifulSoup(source,'lxml')
        #soup
        table_rows=soup.findAll("tr",{"class":"item"})
        info=[]
        links=[]
        u=[]
        for i in table_rows:
            row=[]
            alpha=[]
            atag=i.findAll('a')
            for a in atag:
                
                alpha.append(a['href'])
            links.append(alpha[0])
            td=i.findAll('td')
            for t in td:
                
                row.append(t.text)
            row.append(alpha[1])    
            info.append(row)    


        for i in info:
             for d,j in enumerate(i):
                    if '\t' in j or "\n" in j:
                        j=j.split()
                        j=' '.join(j)
                        i[d]=j
                    
                        
                    
        for i in range(len(links)):
            s="https://www.4adi.com/4adi/"+links[i]
            source=requests.get(s).text
            soup=BeautifulSoup(source,'lxml')
            table=soup.findAll("table")
            table=table[1]
            rows=table.findAll("tr")
            for r in rows:
                
                h=[]
                td_m=r.findAll('td')
                for td in td_m:
                    info[i].append(td.text)
                

        for q in info:
            
            u.append(q)
        

    return (u)

# %%
asa=fun()
print(asa)

# %%
https://www.4adi.com/render.cz?method=searchProducts&categoryId=&keywords=FERT16-S

# %%
article_number
# Out:
# ['FERT16-S',
#  'FERT16-C',
#  'HEPC13-S',
#  'HEPC13-P',
#  'HEPC13-A',
#  'HEPC12-S',
#  'HEPC12-P',
#  'HEPC12-A',
#  'HEPC11-S',
#  'EP22-P',
#  'EP22-A',
#  'EP21-S',
#  'EP21-P',
#  'EP21-A',
#  'EP11-S',
#  'EP11-P',
#  'EP11-A',
#  'ENST16-M',
#  'ENST15-R-250',
#  'ENST15-R-100',
#  'EP31-A',
#  'ENST13-R-1000',
#  'EP31-P',
#  'ENST12-C',
#  'ENST13-R-250',
#  'EPO11-M',
#  'ERAB12-S',
#  'ERAB12-P',
#  'ERAB12-A',
#  'ERAB11-S',
#  'ERAB11-P',
#  'ERAB11-A',
#  'ERA361-P',
#  'ERA361-A',
#  'ERA12-C',
#  'ERA12-A',
#  'ERA11-M',
#  'EPR11-S',
#  'EP41-S',
#  'EP41-P',
#  'EP41-A',
#  'EP32-S',
#  'EP32-P',
#  'EP32-A',
#  'EP31-S',
#  'MCD045-B',
#  'MCD044-PE',
#  'MCD044-M',
#  'EST22-P',
#  'EST22-A',
#  'EST21-S',
#  'EST21-P',
#  'ERB14-A',
#  'ERB13-S',
#  'ERB13-P',
#  'ERB13-A',
#  'ERB12-S',
#  'ERB12-P',
#  'ERB12-A',
#  'eNOS32-A',
#  'ERB21-S',
#  'EVGP20-R-10',
#  'EVGP32-R-10',
#  'EVGP31-R-1000',
#  'EVGP31-R-100',
#  'EVGP31-R-10',
#  'EVGP31-BTN',
# ...

# %%
data=pd.read_excel("ITK_Alpha_newproducts.xlsx")
article_number=list(data["Article number"])
#article_number[0]
file= open("4adi.txt","a+")
def extraction():
    e=[]
    for x in range(500,600):
        print("file number:"+str(x) )
        s="https://www.4adi.com/render.cz?method=searchProducts&categoryId=&keywords="+article_number[x]
        source=requests.get(s).text
        soup=BeautifulSoup(source,'lxml')
        file.write(s)
        table=soup.findAll("tbody")
        #print(table)
        for t in table:
            table_rows=t.findAll("tr",{"class":"item"})
            links=[]
            row_data=[]
            for tr in table_rows:

                alpha=[]
                atag=tr.findAll('a')
                for a in atag:

                    alpha.append(a['href'])
                links.append(alpha[0])
                tabd=tr.findAll("td")
                row=[]
                for i in tabd:

                    row.append(i.text)
                row.append(alpha[1])
                row_data.append(row)
        for i in row_data:
            
            for d,j in enumerate(i):
                

                if '\t' in j or "\n" in j:
                    j=j.split()
                    j=' '.join(j)
                    i[d]=j

        for i in range(len(links)):
            
            
            s="https://www.4adi.com/4adi/"+links[i]
            source=requests.get(s).text
            soup=BeautifulSoup(source,'lxml')
            table=soup.findAll("table")
            table=table[1]
            rows=table.findAll("tr")
            for r in rows:

                h=[]
                td_m=r.findAll('td')
                for td in td_m:
                    

                    row_data[i].append(td.text)
        for i in row_data:
            e.append(i)




    return e

# %%
a=extraction()
print(a)
# Out:
# file number:500
# file number:501
# file number:502
# file number:503
# file number:504
# file number:505
# file number:506
# file number:507
# file number:508
# file number:509
# file number:510
# file number:511
# file number:512
# file number:513
# file number:514
# file number:515
# file number:516
# file number:517
# file number:518
# file number:519
# file number:520
# file number:521
# file number:522
# file number:523
# file number:524
# file number:525
# file number:526
# file number:527
# file number:528
# file number:529
# file number:530
# file number:531
# file number:532
# file number:533
# file number:534
# file number:535
# file number:536
# file number:537
# file number:538
# file number:539
# file number:540
# file number:541
# file number:542
# file number:543
# file number:544
# file number:545
# file number:546
# file number:547
# file number:548
# file number:549
# file number:550
# file number:551
# file number:552
# file number:553
# file number:554
# ...

# %%
def extraction():
    
    e=[]
    for x in range(1,50):
        print("file number:"+str(x) )
        s="https://www.4adi.com/render.cz?method=searchProducts&categoryId=&keywords="+article_number[200]
        source=requests.get(s).text
        soup=BeautifulSoup(source,'lxml')
        file.write(s)
        table=soup.findAll("tbody")
        #print(table)
        for t in table:
            
            table_rows=t.findAll("tr",{"class":"item"})
            links=[]
            row_data=[]
            for tr in table_rows:
                

                alpha=[]
                atag=tr.findAll('a')
                for a in atag:

                    alpha.append(a['href'])
                links.append(alpha[0])
                tabd=tr.findAll("td")
                row=[]
                for i in tabd:

                    row.append(i.text)
                row.append(alpha[1])
                row_data.append(row)
        for i in row_data:
            
            for d,j in enumerate(i):
                

                if '\t' in j or "\n" in j:
                    j=j.split()
                    j=' '.join(j)
                    i[d]=j

        for i in range(len(links)):
            
            
            s="https://www.4adi.com/4adi/"+links[i]
            source=requests.get(s).text
            soup=BeautifulSoup(source,'lxml')
            table=soup.findAll("table")
            table=table[1]
            rows=table.findAll("tr")
            for r in rows:

                h=[]
                td_m=r.findAll('td')
                for td in td_m:
                    

                    row_data[i].append(td.text)
        for i in row_data:
            e.append(i)
        #print(len(e))
        #print(e)



    return e

# %%
a=extraction()
print(a)
# Out:
# file number:1
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-63-425deab68ad8> in <module>
# ----> 1 a=extraction()
#       2 print(a)
#
# <ipython-input-62-b0b44d704579> in extraction()
#      31                 row.append(alpha[1])
#      32                 row_data.append(row)
# ---> 33         for i in row_data:
#      34
#      35             for d,j in enumerate(i):
#
# UnboundLocalError: local variable 'row_data' referenced before assignment

# %%
len(a)

# %%
a
# Out:
# [['DNASE21-P',
#   'Human Deoxyribonuclease II (Dnase II) Control/blocking peptide # 1',
#   'Peptide',
#   '',
#   '100 ug',
#   '95.0',
#   '/product/pdf/DNASE21-S-A-P.pdf',
#   'Antigen',
#   'A 14-aa peptide (designated DNASE21-P, control/blocking peptide) near the C-terminus of human  Dnase II (1) was synthesized, coupled to KLH',
#   'Form',
#   'Antigen/blocking Peptide',
#   'Product Type',
#   'Peptide',
#   'SpCrossreactivity',
#   'The DNASE21-P peptide sequence is not well conserved in mouse Dnase II.  We recommend the use of DNASE22-A for the study of mouse Dnase II.  DNASE21-P has no significant sequence homology with other lysosomal enzymes.  Control peptide, because of its low mol. Wt (<3 kDa), is not suitable for Western.  It should be used for ELISA or antibody blocking experiments',
#   'SpeciesReactivity',
#   'Human',
#   'SugApplications',
# ...

# %%
listing = []
for i, j in enumerate(a):
    v = []
    # print(j)
    c_d = []
    catalog_number = j[0]
    name = j[1]
    typee = j[2]
    size = j[4]
    price = j[5]
    pdf = j[6]
    v.append(j[7:])
    for x in v:
        dict1 = {}
        for g, n in enumerate(x):
            # print(g,n)
            try:
                g = g * 2
                data = x[g]
                desc = x[g + 1]
                dict1.update({data: desc})
            except:
                pass
        dict1.update({"Catalog Number": catalog_number, "Name": name, "Product Type": typee
                         , "Size": size, "Price": price, "PDF REFERENCE": pdf})

    listing.append(dict1)

pd.max_columns=150
alpha_data=pd.DataFrame(listing)

export_csv = alpha_data.to_csv (r'C:\Users\omama\Desktop\export_alphagain.csv', index = None, header=True) #Don't forget to add '.csv' at the end of the path
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-65-22dee715a2e6> in <module>
#      30 alpha_data=pd.DataFrame(listing)
#      31
# ---> 32 export_csv = alpha_data.to_csv (r'C:\Users\omama\Desktop\export_alphagain.csv', index = None, header=True) #Don't forget to add '.csv' at the end of the path
#
# D:\anacondas\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3226             decimal=decimal,
#    3227         )
# -> 3228         formatter.save()
#    3229
#    3230         if path_or_buf is None:
#
# D:\anacondas\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     181                 self.mode,
# ...
